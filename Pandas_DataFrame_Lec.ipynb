# %% [markdown]
# # Creating DataFrames from various file formats

# %% [markdown]
# ### From a CSV file:
# - The read_csv function can be used to read data from a CSV file into a DataFrame, as shown in the following

# %%
import pandas as pd
olympic_data=pd.read_csv("https://raw.githubusercontent.com/svkarthik86/Advanced-python/main/olympics.csv",skiprows=4)
olympic_data
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 0       Athens     1896   Aquatics         Swimming         HAJOS, Alfred
# 1       Athens     1896   Aquatics         Swimming      HERSCHMANN, Otto
# 2       Athens     1896   Aquatics         Swimming     DRIVAS, Dimitrios
# 3       Athens     1896   Aquatics         Swimming    MALOKINIS, Ioannis
# 4       Athens     1896   Aquatics         Swimming    CHASAPIS, Spiridon
# ...        ...      ...        ...              ...                   ...
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender                       Event Event_gender   Medal
# ...

# %% [markdown]
# # Data Validation:

# %%
olympic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29216 entries, 0 to 29215
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          29216 non-null  object
#  1   Edition       29216 non-null  int64
#  2   Sport         29216 non-null  object
#  3   Discipline    29216 non-null  object
#  4   Athlete       29216 non-null  object
#  5   NOC           29216 non-null  object
#  6   Gender        29216 non-null  object
#  7   Event         29216 non-null  object
#  8   Event_gender  29216 non-null  object
#  9   Medal         29216 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 2.2+ MB

# %%
Looking sample of Data:
# Out:
#   Input In [3]
#     Looking sample of Data:
#             ^
# SyntaxError: invalid syntax

# %%
olympic_data.head(6)# default head n=5

# %%
olympic_data.tail(4)# default tail n=5

# %%
#fliter the Edition 2008  data
olympic_data[(olympic_data["Edition"]==2008)&(olympic_data['Medal']=="Gold")]

# %% [markdown]
# # DataFrame Attributes

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
olympic_data.head(3)

# %% [markdown]
# # index
# - The index (row labels) of the DataFrame.

# %%
olympic_data.index #row index

# %% [markdown]
# # column
# - The column labels of the DataFrame.

# %%
olympic_data.columns # column index

# %% [markdown]
# # axes
# - Return a list representing the axes of the DataFrame.
# - It has the row axis labels and column axis labels as the only members. They are returned in that order.

# %%
olympic_data.axes # row and column index

# %% [markdown]
# # ndim
# - Return an int representing the number of axes / array dimensions.
# - Return 1 if Series. Otherwise return 2 if DataFrame.

# %%
olympic_data.ndim # DF always 2D

# %% [markdown]
# # shape
# - Return a tuple representing the dimensionality of the DataFrame.

# %%
olympic_data.shape # row,column

# %% [markdown]
# # size
# - Return an int representing the number of elements in this object.
# - Return the number of rows if Series. Otherwise return the number of rows times number of columns if DataFrame.

# %%
olympic_data.size #multiplication of shape# total number of Elements

# %% [markdown]
# # dtype
# - Return the dtypes in the DataFrame.
# - This returns a Series with the data type of each column. The result’s index is the original DataFrame’s columns. Columns with mixed types are stored with the object dtype. See the User Guide for more.

# %%
olympic_data.dtypes # return data type of each columns

# %% [markdown]
# # count
# - Count non-NA cells for each column or row.

# %%
import numpy as np
df = pd.DataFrame({"Person":["John", "Myla", "Lewis", "John", "Myla"],
                   "Age": [24., np.nan, 21., 33, 26],
                   "Single": [False, True, True, True, False]})

# %%
df

# %%
df.count()

# %%
olympic_data.count()

# %%
olympic_data.T # transpose of DataFrame # row to col

# %% [markdown]
# # empty

# %%
olympic_data.empty # Df is empty

# %%
empty_df=pd.DataFrame([])
empty_df

# %%
empty_df.empty

# %%
print(dir(df)) # methods and attributes associated with DataFrame Object

# %%
olympic_data.values# values in ndarray

# %% [markdown]
# ### From an Excel file:
# - Pandas provides support for importing data from both xls and xlsx file formats using the pd.read_excel function.

# %%
file_path=r"C:\Users\karthick\COVID-19.xlsx"
covid19_data=pd.read_excel(file_path,sheet_name=[1,2]) #deafult sheet is first sheet
covid19_data

# %%
file_path=r"C:\Users\karthick\COVID-19.xlsx"
covid19_data_all=pd.read_excel(file_path,sheet_name=[0,1,2,"sheet4"]) #deafult sheet is first sheet
covid19_data_all 
#sheet_name=[0,1,2,"sheet4"]  Load first, second,third and sheet named "Sheet4"  as a dict of `DataFrame

# %%
for key in covid19_data_all:
    print(covid19_data_all[key])

# %%
covid19_data_all['sheet4']

# %%
covid19_data_all[0] #sheet1 data

# %%
covid19_data_all[1] #sheet1 data

# %%
covid19_data_all[2] #sheet3 data

# %%
covid19_data_all[3] #sheet4 data

# %% [markdown]
# # Read Data From Google Sheet

# %%
url="https://docs.google.com/spreadsheets/d/1zMSyXLQMHRuEpagVDYi9SPl3FD3AKGTeKoidOlIEIo4/edit#gid=1191179893"

# %%
url.replace('/edit#gid=', '/export?format=csv&gid=')

# %%
url="https://docs.google.com/spreadsheets/d/1zMSyXLQMHRuEpagVDYi9SPl3FD3AKGTeKoidOlIEIo4/edit#gid=1191179893"
data_file = url.replace('/edit#gid=', '/export?format=csv&gid=')
std_adapt=pd.read_csv(data_file)
std_adapt

# %% [markdown]
# ### From a JSON file:
# - JSON stands for JavaScript Object Notation and is a cross-platform file format for transmitting and exchanging data between the client and server. Pandas provides the function read_json to read data from a JSON file.

# %%
json_data=pd.read_json('https://raw.githubusercontent.com/svkarthik86/Advance-Python-Numpy/main/countries.json')
json_data

# %% [markdown]
# # From a HTML file:

# %%
pd.read_html()
Read HTML tables into a ``list`` of ``DataFrame`` objects.

# %%
table_MN = pd.read_html('https://en.wikipedia.org/wiki/Minnesota')
table_MN

# %%
len(table_MN)

# %%
table_MN[2]

# %%
 pd.read_html('https://en.wikipedia.org/wiki/Minnesota', 
                          match='Average daily maximum and minimum temperatures for selected cities in Minnesota')[0]

# %%
table_MN_1 = pd.read_html('https://en.wikipedia.org/wiki/Minnesota', match='Election results from statewide races')
table_MN_1[0]

# %%
type(table_MN_1)

# %%
len(table_MN_1)

# %%
# [ DataFrame ]

# %%
df = table_MN_1[0]
df

# %%
pd.read_html('https://en.wikipedia.org/wiki/Minnesota', 
             match='Average daily maximum and minimum temperatures for selected cities in Minnesota')[0]

# %%
pd.read_html("https://www.nseindia.com/get-quotes/equity?symbol=SBIN")#, match="SBIN (Period 17-05-2022 to 17-06-2022")

# %%
file_path="https://raw.githubusercontent.com/svkarthik86/Advanced-python/main/test.html"
html_data=pd.read_html(file_path)
html_data

# %%
type(html_data)

# %% [markdown]
# # Acessing Data from DataFrame

# %%
olympic_data.head(3)

# %% [markdown]
# # Accesing column using []

# %%
olympic_data['City'] # Series of City column

# %%
olympic_data[['NOC','City','Edition','Sport']] # DataFrame # slicing more than one

# %% [markdown]
# # Using . object:

# %%
olympic_data.NOC

# %% [markdown]
# # Using Loc: String based index

# %%
import pandas as pd
olympic_data=pd.read_csv("https://raw.githubusercontent.com/svkarthik86/Advanced-python/main/olympics.csv",skiprows=4)
olympic_data[:10,['City','NOC']]# loc[row,column]

# %%
df1=pd.DataFrame([[23,45,56],[45,67,67],[45,67,78]])
df1

# %%
df1.loc[0:1,0:2:2]

# %%
df1.iloc[0:1,1:2]

# %%
olympic_data.iloc[0:10,2:3]

# %%
olympic_data.loc[:,'Athlete':'Medal':2]  # start:stop:step both included for loc

# %%
olympic_data[olympic_data['Medal']=="Silver"]    # who are all won the silver medal

# %% [markdown]
# # using iloc: #integer based , numerical index

# %%
olympic_data.head(3)

# %%
olympic_data.iloc[0:10:2,-1] #iloc[row,column]     # start:stop:step

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
using .iloc  : all rows and columns-Edition,Event_gender,Medal

# %%
olympic_data.iloc[:,[1,8,9]]

# %%
olympic_data.rename(columns={"Year":"Edition"},inplace=True)

# %%
olympic_data

# %%
olympic_data['NOC']

# %%
olympic_data.NOC

# %%
type(olympic_data.NOC)

# %%
olympic_data.columns

# %%
olympic_data[['Edition', 'City','Athlete', 'Medal']]

# %% [markdown]
# ## Modifying DataFrame objects
# -  to change the names of columns and add and delete columns and rows.

# %% [markdown]
# ### Renaming columns
# - The names of the columns can be changed using the rename method.
# - A dictionary is passed as an argument to this method.
# - The keys for this dictionary are the old column names, and the values are the new column names.

# %%
combined_ages=pd.DataFrame({'class 1':[22,40],'class 2':[24,50],'class 3':[20,45]})
combined_ages

# %%
combined_ages

# %%
combined_ages.rename(columns={'class 1':'batch1','class 2':'batch2','class 3':'batch 3'},inplace=True)
combined_ages

# %%
combined_ages.batch 3

# %%
combined_ages.rename(columns={"batch 3":"batch3"},inplace=True)
combined_ages

# %%
combined_ages.batch3

# %% [markdown]
# The reason we use the inplace parameter so that the changes are made in the actual DataFrame object
# Renaming can also be done by accessing the columns attribute directly and mentioning the new column names in an array

# %% [markdown]
# Renaming can also be done by accessing the columns attribute directly and mentioning
# the new column names in an array, as shown in the following example.

# %%
combined_ages.columns

# %%
#2nd method
combined_ages.columns=['class 1','class 2','class 3']
combined_ages

# %%
combined_ages.columns.str

# %%
combined_ages.columns=combined_ages.columns.str.replace(' ','_')

# %%
combined_ages

# %% [markdown]
# - Renaming using the dictionary format is a more straightforward method for renaming columns, and the changes are made to the original DataFrame object.
# - The disadvantage with this method is that one needs to remember the order of the columns in the DataFrame.
# - When we used the rename method, we used a dictionary where we knew which column names we were changing.

# %% [markdown]
# ### Replacing values or observations in a DataFrame
# - The replace method can be used to replace values in a DataFrame.
# - We can again use the dictionary format, with the key/value pair representing the old and new values. Here, we replace the value 22 with the value 33.

# %%
combined_ages

# %%
combined_ages.replace({22:45},inplace=True)
combined_ages

# %%
combined_ages.replace({45:55},inplace=True)
combined_ages

# %%
combined_ages.replace({33:100},inplace=True)
combined_ages

# %% [markdown]
# ### Adding a new column to a DataFrame
# There are four ways to insert a new column in a DataFrame

# %% [markdown]
# ### 1.With the indexing operator, [ ]

# %%
combined_ages

# %%
combined_ages['class5']=[18,50]# if name column name is already present, then overwrite data, else create new column
combined_ages

# %% [markdown]
# By mentioning the column name as a string within the indexing operator and assigning it values, we can add a column.

# %% [markdown]
# ### 2.Using the insert method

# %%
combined_ages.insert(2,'batchY',[10,20])# if column name is already exist will throw error
combined_ages

# %% [markdown]
# ### 3.Using the loc indexer

# %%
import numpy as np
combined_ages.loc[:,'batchZ']=np.arange(12,14) # if Column is exist it will overwrite the data else create new column
combined_ages

# %% [markdown]
# ### 4.Using the concat function

# %%
batchxy=pd.Series([45,50])
batchxy

# %%
combined_ages=pd.concat([combined_ages,batchxy],axis=1,ignore_index=True)
combined_ages

# %% [markdown]
# - In summary, we can add a column to a DataFrame using the indexing operator, loc indexer, insert method, or concat function. The most straightforward and commonly used method for adding a column is by using the indexing operator [].

# %% [markdown]
# ## Inserting rows in a DataFrame
# - There are two methods for adding rows in a DataFrame, either by using the append method or with the concat function.

# %%
combined_ages=pd.DataFrame({'class 1':[22,40],'class 2':[24,50],'class 3':[20,45]})
combined_ages

# %% [markdown]
# ### 1.Using the append method

# %%
combined_ages=combined_ages.append({'class 1':35,'class 2':33,'class 3':21},ignore_index=True)
combined_ages

# %%
df=pd.DataFrame({'class 1':[45],'class 2':[43],'class 3':[41]})
df

# %%
combined_ages.append(df)

# %%
combined_ages=combined_ages.append([[45,56,78]],ignore_index=True)
combined_ages

# %%
df = pd.DataFrame([[1, 2], [3, 4]], columns=list('AB'), index=['x', 'y'])
df

# %%
df2 = pd.DataFrame([[5, 6], [7, 8]], columns=list('AB'), index=['x', 'y'])
df2

# %%
df.append(df2)

# %%
x=df.append(df2)

# %%
x.index

# %%
x.loc['x']

# %% [markdown]
# - the ignore_index=True parameter prevents an error from being thrown.This parameter resets the index.
# - Note that the append method does not have an inplace parameter that would ensure that the changes reflect in the original object

# %% [markdown]
# ### 2.Using the pd.concat function

# %%
combined_ages=pd.DataFrame({'class 1':[22,40],'class 2':[24,50],'class 3':[20,45]})
combined_ages

# %%
new_row=pd.DataFrame([{'class 1':32,'class 2':37,'class 3':41}])
new_row

# %%
df=pd.DataFrame([{'class 1':672,'class 2':437,'class 3':415}])
df

# %%
combined_ages=pd.concat([combined_ages,new_row,df],axis=0,ignore_index=True) #axis=0 default
combined_ages

# %% [markdown]
# The pd.concat function is used to add new rows as shown in the preceding syntax. The new row to be added is defined as a DataFrame object. Then the pd.concat function is called and the names of the two DataFrames (the original DataFrame and the new row defined as a DataFrame) are passed as arguments.

# %% [markdown]
# ## Deleting columns from a DataFrame
# - Three methods can be used to delete a column from a DataFrame

# %%
combined_ages=pd.DataFrame({'class 1':[22,40],'class 2':[24,50],'class 3':[20,45]})
combined_ages
# Out:
#    class 1  class 2  class 3
# 0       22       24       20
# 1       40       50       45

# %%
combined_ages['class 3']
# Out:
# 0    20
# 1    45
# Name: class 3, dtype: int64

# %% [markdown]
# ### 1.del function

# %%
del combined_ages['class 3'] # deletion occurs in original DataFrame itself.
combined_ages
# Out:
#    class 1  class 2
# 0       22       24
# 1       40       50

# %% [markdown]
# The preceding statement deletes the last column (with the name,“class 3”).
# Note that the deletion occurs inplace, that is, in the original DataFrame itself.

# %% [markdown]
# ### 2.Using the pop method

# %%
combined_ages.pop('class 1')# deletion occurs in original DataFrame itself.
# Out:
# 0    22
# 1    40
# Name: class 1, dtype: int64

# %%
combined_ages
# Out:
#    class 2
# 0       24
# 1       50

# %% [markdown]
# # 3.drop()

# %%
combined_ages=pd.DataFrame({'class 1':[22,40],'class 2':[24,50],'class 3':[20,45]})
combined_ages
# Out:
#    class 1  class 2  class 3
# 0       22       24       20
# 1       40       50       45

# %%
combined_ages.drop(["class 1","class 3"],axis=1,inplace=False) #remove the second row, which has a row index of 3
# Out:
#    class 2
# 0       24
# 1       50

# %%
combined_ages
# Out:
#    class 1  class 2  class 3
# 0       22       24       20
# 1       40       50       45

# %% [markdown]
# The column(s) that needs to be dropped is mentioned as a string within a list, which is then passed as an argument to the drop
# method. Since the drop method removes rows (axis=0) by default, we need to specify the axis value as “1” if we want to remove a
# column.
# Unlike the del function and pop method, the deletion using the drop method does not occur in the original DataFrame object, and
# therefore, we need to add the inplace parameter.

# %% [markdown]
# ### Deleting a row from a DataFrame
# - There are two methods for removing rows from a DataFrame – either by using a Boolean selection or by using the drop method

# %%
combined_ages=pd.DataFrame({'class 1':[22,40],'class 2':[24,50],'class 3':[20,45]})
combined_ages
# Out:
#    class 1  class 2  class 3
# 0       22       24       20
# 1       40       50       45

# %%
~(combined_ages.values<50)
# Out:
# array([[False, False, False],
#        [False,  True, False]])

# %% [markdown]
# ### 1.Using a Boolean selection

# %%
combined_ages[~(combined_ages.values<50)]
# Out:
#    class 1  class 2  class 3
# 1       40       50       45

# %%
combined_ages
# Out:
#    class 1  class 2  class 3
# 0       22       24       20
# 1       40       50       45

# %% [markdown]
# ### Using the drop method

# %%
combined_ages.drop([0,1],axis=0,inplace=False) #remove the second row, which has a row index of 3
# Out:
# Empty DataFrame
# Columns: [class 1, class 2, class 3]
# Index: []

# %% [markdown]
# hus, we can use either a Boolean selection or the drop method to remove rows from a DataFrame.Since the drop method works with the removal of both rows and columns, it can be used uniformly.Remember to add the required parameters to the drop method.
# For removing columns, the axis (=1) parameter needs to be added. For changes to reflect in the original DataFrame, the inplace (=True) parameter needs to be included.

# %% [markdown]
# ## Exercise problems:

# %% [raw]
# Exercise problems:
#
# read the data from given url to DataFrame as sales_data
# https://raw.githubusercontent.com/svkarthik86/Assignment/main/Sales_Data/Sales_January_2019.csv
#
# Q1.Rename The column name with valid format:
#     oldname:Order ID,Product,Quantity Ordered,Price Each,Order Date,Purchase Address
#     newname:Order_ID,Product,Quantity_Ordered,Price_Each,Order_Date,Purchase_Address
#
# Q2.insert new column as order_price
# compute order_price =Price_Each*Quantity_Ordered
#
# Q3.Delete the column Purchase_Address
#
# Q4.insert new row data as  at last
# 100001,OnePhone,1,600, 01/22/19 21:25,600
#
# Q5.Gruopby Product and apply the aggregate function min,max,mean on order_price

# %% [markdown]
# # Solution:

# %%
url="https://raw.githubusercontent.com/svkarthik86/Assignment/main/Sales_Data/Sales_January_2019.csv"
sales_data=pd.read_csv(url)
sales_data.head(4)
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
# 2   141236          Wired Headphones                2      11.99
# 3   141237          27in FHD Monitor                1     149.99
#
#        Order Date                       Purchase Address
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001

# %% [markdown]
# Q1.Rename The column name with valid format:
#     oldname:Order ID,Product,Quantity Ordered,Price Each,Order Date,Purchase Address
#     newname:Order_ID,Product,Quantity_Ordered,Price_Each,Order_Date,Purchase_Address

# %%
sales_data.columns=sales_data.columns.str.replace(" ","_")

# %%
sales_data.columns
# Out:
# Index(['Order_ID', 'Product', 'Quantity_Ordered', 'Price_Each', 'Order_Date',
#        'Purchase_Address'],
#       dtype='object')

# %% [markdown]
# Q2.insert new column as order_price
# compute order_price =Price_Each*Quantity_Ordered

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9723 entries, 0 to 9722
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          9697 non-null   object
#  1   Product           9697 non-null   object
#  2   Quantity_Ordered  9697 non-null   object
#  3   Price_Each        9697 non-null   object
#  4   Order_Date        9697 non-null   object
#  5   Purchase_Address  9697 non-null   object
# dtypes: object(6)
# memory usage: 455.9+ KB

# %%
9723- 9697
# Out:
# 26

# %%
Find the nan/null value  isna() ,isnull()

# %%
sales_data.Price_Each.isna()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9718    False
# 9719    False
# 9720    False
# 9721    False
# 9722    False
# Name: Price_Each, Length: 9723, dtype: bool

# %%
sales_data[sales_data.Price_Each.isna()] # all nan valued rows
# Out:
#      Order_ID Product Quantity_Ordered Price_Each Order_Date Purchase_Address
# 664       NaN     NaN              NaN        NaN        NaN              NaN
# 678       NaN     NaN              NaN        NaN        NaN              NaN
# 797       NaN     NaN              NaN        NaN        NaN              NaN
# 876       NaN     NaN              NaN        NaN        NaN              NaN
# 1299      NaN     NaN              NaN        NaN        NaN              NaN
# 1491      NaN     NaN              NaN        NaN        NaN              NaN
# 1699      NaN     NaN              NaN        NaN        NaN              NaN
# 3047      NaN     NaN              NaN        NaN        NaN              NaN
# 3082      NaN     NaN              NaN        NaN        NaN              NaN
# 3584      NaN     NaN              NaN        NaN        NaN              NaN
# 3659      NaN     NaN              NaN        NaN        NaN              NaN
# ...

# %%
sales_data=sales_data[~(sales_data.Price_Each.isna())] # cleaned data # remoned nan

# %%
sales_data['order_price'] =sales_data['Price_Each'].astype('float')*sales_data['Quantity_Ordered'].astype('float')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [247], in <cell line: 1>()
# ----> 1 sales_data['order_price'] =sales_data['Price_Each'].astype('float')*sales_data['Quantity_Ordered'].astype('float')
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# ...

# %%
sales_data=sales_data[~(sales_data['Price_Each']=='Price Each')]

# %%
sales_data['order_price'] =sales_data.loc[:,'Price_Each'].astype('float')*sales_data.loc[:,'Quantity_Ordered'].astype('float')
# Out:
# C:\Users\karthick\AppData\Local\Temp\ipykernel_8804\4164129956.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales_data['order_price'] =sales_data.loc[:,'Price_Each'].astype('float')*sales_data.loc[:,'Quantity_Ordered'].astype('float')

# %%
sales_data
# Out:
#      Order_ID                   Product Quantity_Ordered Price_Each  \
# 0      141234                    iPhone                1        700
# 1      141235  Lightning Charging Cable                1      14.95
# 2      141236          Wired Headphones                2      11.99
# 3      141237          27in FHD Monitor                1     149.99
# 4      141238          Wired Headphones                1      11.99
# ...       ...                       ...              ...        ...
# 9718   150497              20in Monitor                1     109.99
# 9719   150498          27in FHD Monitor                1     149.99
# 9720   150499           ThinkPad Laptop                1     999.99
# 9721   150500    AAA Batteries (4-pack)                2       2.99
# 9722   150501              Google Phone                1        600
#
#           Order_Date                       Purchase_Address  order_price
# 0     01/22/19 21:25        944 Walnut St, Boston, MA 02215       700.00
# ...

# %%
Q3.Delete the column Purchase_Address

# %%
del sales_data['Purchase_Address']

# %%
sales_data.head(2)
# Out:
#   Order_ID                   Product Quantity_Ordered Price_Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
#
#        Order_Date
# 0  01/22/19 21:25
# 1  01/28/19 14:15

# %%
Q4.insert new row data as  at last
100001,OnePhone,1,600, 01/22/19 21:25,600

# %%
sales_data.append({"Order_ID":100001,"Product":"OnePhone","Quantity_Ordered":1,
                   "Price_Each":600,"Order_Date":"01/22/19 21:25,600"},ignore_index=True)
# Out:
# C:\Users\karthick\AppData\Local\Temp\ipykernel_8804\2654553506.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sales_data.append({"Order_ID":100001,"Product":"OnePhone","Quantity_Ordered":1,
#      Order_ID                   Product Quantity_Ordered Price_Each  \
# 0      141234                    iPhone                1        700
# 1      141235  Lightning Charging Cable                1      14.95
# 2      141236          Wired Headphones                2      11.99
# 3      141237          27in FHD Monitor                1     149.99
# 4      141238          Wired Headphones                1      11.99
# ...       ...                       ...              ...        ...
# 9719   150498          27in FHD Monitor                1     149.99
# 9720   150499           ThinkPad Laptop                1     999.99
# 9721   150500    AAA Batteries (4-pack)                2       2.99
# ...

# %% [markdown]
# # Indexing
# - Indexing is fundamental to Pandas and is what makes retrieval and access to data much faster compared to other tools.
# - It is crucial to set an appropriate index to optimize performance.
# - An index is implemented in NumPy as an immutable (cannot be modified) array and contains hashable objects.
# - A hashable object is one that can be converted to an integer value based on its contents (similar to mapping in a dictionary). Objects with different values will have different hash values.
# - Pandas has two types of indexes - a row index (vertical) with labels attached to rows, and a column index with labels (column names) for every column.
# - Let us now explore index objects – their data types, their properties, and how they speed up access to data.

# %% [markdown]
# ### Type of an index object
# - An index object has a data type, some of which are listed here.
# - Index: This is a generic index type; the column index has this type.
# - RangeIndex: Default index type in Pandas (used when an index is not defined separately), implemented as a range of increasing integers. This index type helps with saving memory.
# - Int64Index: An index type containing integers as labels. For this index type, the index labels need not be equally spaced, whereas this is required for an index of type RangeIndex.
# - Float64Index: Contains floating-point numbers (numbers with a decimal point) as index labels.
# - IntervalIndex: Contains intervals (for instance, the interval between two integers) as labels.
# - CategoricalIndex: A limited and finite set of values.
# - DateTimeIndex: Used to represent date and time, like in time-series data.
# - PeriodIndex: Represents periods like quarters, months, or years.
# - TimedeltaIndex: Represents duration between two periods of time or two dates.
# - MultiIndex: Hierarchical index with multiple levels.

# %% [raw]
# Learn more about types of indexes here: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Index.html

# %% [markdown]
# ## Creating a custom index and using columns as indexes
# - When a Pandas object is created, a default index is created of the type RangeIndex
# - An index of this type has the first label value as 0 and the second label as 1, following an arithmetic progression with a spacing of one integer.
# - We can set a customized index, using either the index parameter or attribute.
# - In the Series and DataFrame objects in the absence of labels for the index object, the default index (of type RangeIndex) was used.
# - We can use the index parameter when we define a Series or DataFrame to give custom values to the index labels.

# %%
import pandas as pd
periodic_table=pd.DataFrame({'Element':['Hydrogen','Helium','Lithium','Beryllium','Boron']},index=['H','He','Li','Be','B'])
periodic_table
# Out:
#       Element
# H    Hydrogen
# He     Helium
# Li    Lithium
# Be  Beryllium
# B       Boron

# %%
periodic_table.index
# Out:
# Index(['H', 'He', 'Li', 'Be', 'B'], dtype='object')

# %% [markdown]
# If we skip the index parameter during the creation of the object, we can set the labels using the index attribute

# %%
periodic_table.index=['H','He','Li','Be','B']

# %% [markdown]
# ### set_index()
# - The set_index method can be used to set an index using an existing column
# - ``` DataFrame.set_index(keys, drop=True, append=False, inplace=False, verify_integrity=False)```

# %%
periodic_table1=pd.DataFrame({'Element':['Hydrogen','Helium','Lithium','Beryllium','Boron'],'Symbols':['H','He','Li','Be','B']})
#periodic_table1.set_index(['Symbols'])  #inplace=True
periodic_table1
# Out:
#      Element Symbols
# 0   Hydrogen       H
# 1     Helium      He
# 2    Lithium      Li
# 3  Beryllium      Be
# 4      Boron       B

# %%
periodic_table1.set_index(['Symbols'],inplace=True)

# %%
periodic_table1
# Out:
#            Element
# Symbols
# H         Hydrogen
# He          Helium
# Li         Lithium
# Be       Beryllium
# B            Boron

# %%
periodic_table1.index
# Out:
# Index(['H', 'He', 'Li', 'Be', 'B'], dtype='object', name='Symbols')

# %%
periodic_table1.loc["H",]
# Out:
# Element    Hydrogen
# Name: H, dtype: object

# %% [markdown]
# ### reset_index()
# - The index can be made a column again or reset using the reset_index method:
# - ```DataFrame.reset_index(level=None, drop=False, inplace=False, col_level=0, col_fill='')```
# - Reset the index, or a level of it.
# - Reset the index of the DataFrame, and use the default one instead. If the DataFrame has a MultiIndex, this method can remove one or more levels.

# %%
periodic_table1.reset_index(inplace=True)

# %%
periodic_table1
# Out:
#   Symbols    Element
# 0       H   Hydrogen
# 1      He     Helium
# 2      Li    Lithium
# 3      Be  Beryllium
# 4       B      Boron

# %% [markdown]
# ## index_col parameter
# - We can also set the index when we read data from an external file into a DataFrame,using the index_col parameter, as shown in the following.

# %%
olympic_data=pd.read_csv("https://raw.githubusercontent.com/svkarthik86/Advanced-python/main/olympics.csv"
                         ,skiprows=4,index_col=["Edition"])
olympic_data.head(3)
# Out:
#            City     Sport Discipline            Athlete  NOC Gender  \
# Edition
# 1896     Athens  Aquatics   Swimming      HAJOS, Alfred  HUN    Men
# 1896     Athens  Aquatics   Swimming   HERSCHMANN, Otto  AUT    Men
# 1896     Athens  Aquatics   Swimming  DRIVAS, Dimitrios  GRE    Men
#
#                               Event Event_gender   Medal
# Edition
# 1896                 100m freestyle            M    Gold
# 1896                 100m freestyle            M  Silver
# 1896     100m freestyle for sailors            M  Bronze

# %%
olympic_data[olympic_data["Edition"]==1896]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Edition'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
olympic_data.loc[1896,:]
# Out:
#            City          Sport       Discipline                   Athlete  \
# Edition
# 1896     Athens       Aquatics         Swimming             HAJOS, Alfred
# 1896     Athens       Aquatics         Swimming          HERSCHMANN, Otto
# 1896     Athens       Aquatics         Swimming         DRIVAS, Dimitrios
# 1896     Athens       Aquatics         Swimming        MALOKINIS, Ioannis
# 1896     Athens       Aquatics         Swimming        CHASAPIS, Spiridon
# ...         ...            ...              ...                       ...
# 1896     Athens  Weightlifting    Weightlifting             JENSEN, Viggo
# 1896     Athens  Weightlifting    Weightlifting       ELLIOTT, Launceston
# 1896     Athens      Wrestling  Wrestling Gre-R  CHRISTOPOULOS, Stephanos
# 1896     Athens      Wrestling  Wrestling Gre-R            SCHUMANN, Carl
# 1896     Athens      Wrestling  Wrestling Gre-R          TSITAS, Georgios
#
#          NOC Gender                        Event Event_gender   Medal
# ...

# %%
olympic_data.reset_index(inplace=True)

# %%
olympic_data
# Out:
#        Edition     City      Sport       Discipline               Athlete  \
# 0         1896   Athens   Aquatics         Swimming         HAJOS, Alfred
# 1         1896   Athens   Aquatics         Swimming      HERSCHMANN, Otto
# 2         1896   Athens   Aquatics         Swimming     DRIVAS, Dimitrios
# 3         1896   Athens   Aquatics         Swimming    MALOKINIS, Ioannis
# 4         1896   Athens   Aquatics         Swimming    CHASAPIS, Spiridon
# ...        ...      ...        ...              ...                   ...
# 29211     2008  Beijing  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212     2008  Beijing  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213     2008  Beijing  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214     2008  Beijing  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215     2008  Beijing  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender                       Event Event_gender   Medal
# ...

# %%
olympic_data.set_index(["NOC","Edition"], inplace=True)

# %%
olympic_data
# Out:
#                 City      Sport       Discipline               Athlete Gender  \
# NOC Edition
# HUN 1896      Athens   Aquatics         Swimming         HAJOS, Alfred    Men
# AUT 1896      Athens   Aquatics         Swimming      HERSCHMANN, Otto    Men
# GRE 1896      Athens   Aquatics         Swimming     DRIVAS, Dimitrios    Men
#     1896      Athens   Aquatics         Swimming    MALOKINIS, Ioannis    Men
#     1896      Athens   Aquatics         Swimming    CHASAPIS, Spiridon    Men
# ...              ...        ...              ...                   ...    ...
# GER 2008     Beijing  Wrestling  Wrestling Gre-R        ENGLICH, Mirko    Men
# LTU 2008     Beijing  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas    Men
# ARM 2008     Beijing  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri    Men
# CUB 2008     Beijing  Wrestling  Wrestling Gre-R         LOPEZ, Mijain    Men
# RUS 2008     Beijing  Wrestling  Wrestling Gre-R        BAROEV, Khasan    Men
#
# ...

# %%
olympic_data.index
# Out:
# MultiIndex([('HUN', 1896),
#             ('AUT', 1896),
#             ('GRE', 1896),
#             ('GRE', 1896),
#             ('GRE', 1896),
#             ('GRE', 1896),
#             ('HUN', 1896),
#             ('GRE', 1896),
#             ('GRE', 1896),
#             ('AUT', 1896),
#             ...
#             ('ITA', 2008),
#             ('HUN', 2008),
#             ('KAZ', 2008),
#             ('USA', 2008),
#             ('RUS', 2008),
#             ('GER', 2008),
#             ('LTU', 2008),
#             ('ARM', 2008),
#             ('CUB', 2008),
#             ('RUS', 2008)],
#            names=['NOC', 'Edition'], length=29216)

# %%
olympic_data.loc[('RUS',2008),:]
# Out:
# C:\Users\karthick\AppData\Local\Temp\ipykernel_8804\1504886900.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   olympic_data.loc[('RUS',2008),:]
#                 City      Sport       Discipline              Athlete Gender  \
# NOC Edition
# RUS 2008     Beijing   Aquatics           Diving       GALPERIN, Gleb    Men
#     2008     Beijing   Aquatics           Diving     PAKHALINA, Julia  Women
#     2008     Beijing   Aquatics           Diving   DOBROSKOK, Dmitriy    Men
#     2008     Beijing   Aquatics           Diving       GALPERIN, Gleb    Men
#     2008     Beijing   Aquatics           Diving       KUNAKOV, Yuriy    Men
# ...              ...        ...              ...                  ...    ...
#     2008     Beijing  Wrestling  Wrestling Free.  AKHMEDOV, Bakhtiyar    Men
#     2008     Beijing  Wrestling  Wrestling Gre-R       MANKIEV, Nazyr    Men
#     2008     Beijing  Wrestling  Wrestling Gre-R   ALBIEV, Islam-Beka    Men
# ...

# %% [markdown]
# ### Indexes and speed of data retrieval
# - indexes dramatically improve the speed of access to data.

# %%
periodic_table=pd.DataFrame({'Atomic Number':[1,2,3,4,5],'Element':['Hydrogen','Helium','Lithium','Beryllium','Boron'],
                             'Symbol':['H','He','Li','Be','B']})
periodic_table
# Out:
#    Atomic Number    Element Symbol
# 0              1   Hydrogen      H
# 1              2     Helium     He
# 2              3    Lithium     Li
# 3              4  Beryllium     Be
# 4              5      Boron      B

# %% [markdown]
# ### Searching without using an index
# - Now, try retrieving the element with atomic number 2 without the use of an index and measure the time taken for retrieval using the timeit magic function. When the index is not used, a linear search is performed to retrieve an element, which is relatively time consuming

# %%
periodic_table[periodic_table['Atomic Number']==2]
# Out:
#    Atomic Number Element Symbol
# 1              2  Helium     He

# %%
# %timeit periodic_table[periodic_table['Atomic Number']==2]
# Out:
# 165 µs ± 2.3 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Search using an index
# - Now, set the “Atomic Number” column as the index and use the loc indexer to see how much time the search takes now:

# %%
new_periodic_table=periodic_table.set_index(['Atomic Number'])
# %timeit new_periodic_table.loc[2]
# Out:
# 36.8 µs ± 520 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
new_periodic_table
# Out:
#                  Element Symbol
# Atomic Number
# 1               Hydrogen      H
# 2                 Helium     He
# 3                Lithium     Li
# 4              Beryllium     Be
# 5                  Boron      B

# %%
new_periodic_table.loc[2]
# Out:
# Element    Helium
# Symbol         He
# Name: 2, dtype: object

# %% [markdown]
# ### Immutability of an index
# - the index object is immutable
# - once defined, the index object or its labels cannot be modified.

# %%
periodic_table.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
periodic_table.index[2]
# Out:
# 2

# %%
periodic_table.index[2]=0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [305], in <cell line: 1>()
# ----> 1 periodic_table.index[2]=0
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5021, in Index.__setitem__(self, key, value)
#    5019 @final
#    5020 def __setitem__(self, key, value):
# -> 5021     raise TypeError("Index does not support mutable operations")
#
# TypeError: Index does not support mutable operations

# %% [markdown]
# ## index attributes

# %% [markdown]
# - Some of the attributes of the column index are

# %%
Example:

# %%
periodic_table=pd.DataFrame({'Element':['Hydrogen','Helium','Lithium','Beryllium','Boron']},index=['H','He','Li','Be','B'])
periodic_table
# Out:
#       Element
# H    Hydrogen
# He     Helium
# Li    Lithium
# Be  Beryllium
# B       Boron

# %%
column_index=periodic_table.columns
column_index
# Out:
# Index(['Element'], dtype='object')

# %% [markdown]
# 1.values attribute: Returns the column names

# %%
column_index.values
# Out:
# array(['Element'], dtype=object)

# %% [markdown]
# 2.hasnans attribute: Returns a Boolean True or False value based on the presence of null values.

# %%
column_index.hasnans
# Out:
# False

# %% [markdown]
# 3.nbytes attribute: Returns the number of bytes occupied in memory

# %%
column_index.nbytes
# Out:
# 8

# %% [markdown]
# Further reading: For a complete list of attributes, refer to the following documentation:
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Index.html

# %% [markdown]
# # Exercise

# %%
import pandas as pd
olympic_data=pd.read_csv("https://raw.githubusercontent.com/svkarthik86/Advance-Python-Numpy/main/olympics.csv",skiprows=4)

# %%
olympic_data.index.values # row
# Out:
# array([    0,     1,     2, ..., 29213, 29214, 29215], dtype=int64)

# %%
olympic_data.columns.values # columns
# Out:
# array(['City', 'Edition', 'Sport', 'Discipline', 'Athlete', 'NOC',
#        'Gender', 'Event', 'Event_gender', 'Medal'], dtype=object)

# %%
olympic_data.index.hasnans #row
# Out:
# False

# %%
olympic_data.columns.hasnans #coloumn
# Out:
# False

# %%
olympic_data.index.has_duplicates
# Out:
# False

# %%
olympic_data.columns.has_duplicates
# Out:
# False

# %%
olympic_data.index.nbytes
# Out:
# 128

# %%
olympic_data.columns.nbytes
# Out:
# 80

# %% [markdown]
# ### Data types in Pandas
# - The data types used in Pandas are derived from NumPy, except for the “category” data
# - type for qualitative data, which is defined in Pandas. The common data types include
# - object (for storing mixed data like numbers, strings, etc.)
# - int64 (for integer values)
# - float64 (for numbers with decimal points)
# - Datetime (for storing date and time data)
# - Category (for variables containing only a few distinct values,like ‘True’/’False’, or some limited ordered categories like ‘one’/’two’/’three’/’four’)

# %% [markdown]
# ### Obtaining information about data types

# %%
import pandas as pd
olympic_data=pd.read_csv("https://raw.githubusercontent.com/svkarthik86/Advance-Python-Numpy/main/olympics.csv",skiprows=4)

# %% [markdown]
# #Using the dtypes attribute, we can obtain the type of columns in this DataFrame.
# DataFrame.dtypes

# %%
olympic_data.dtypes # DataFrame
# Out:
# City            object
# Edition          int64
# Sport           object
# Discipline      object
# Athlete         object
# NOC             object
# Gender          object
# Event           object
# Event_gender    object
# Medal           object
# dtype: object

# %% [markdown]
# - Knowing the data types of columns helps us figure out how to analyze the variables.
# - The columns that have the Pandas data type “object” or “category” are categorical variables, whereas variables with data types like “int64” and “float64” are continuous.

# %% [markdown]
# ### Select particular data types
# - Using the select_dtypes method, we can filter the columns based on the type of data you want to select:
# -``` DataFrame.select_dtypes(include=None, exclude=None)```

# %% [markdown]
# DataFrame.select_dtypes(include='object').head() # category
# #This will select all columns that have integer and floating-point data and exclude the rest.
# #The head parameter has been used to limit the number of records being displayed.

# %%
olympic_data.select_dtypes(include='object')
# Out:
#           City      Sport       Discipline               Athlete  NOC Gender  \
# 0       Athens   Aquatics         Swimming         HAJOS, Alfred  HUN    Men
# 1       Athens   Aquatics         Swimming      HERSCHMANN, Otto  AUT    Men
# 2       Athens   Aquatics         Swimming     DRIVAS, Dimitrios  GRE    Men
# 3       Athens   Aquatics         Swimming    MALOKINIS, Ioannis  GRE    Men
# 4       Athens   Aquatics         Swimming    CHASAPIS, Spiridon  GRE    Men
# ...        ...        ...              ...                   ...  ...    ...
# 29211  Beijing  Wrestling  Wrestling Gre-R        ENGLICH, Mirko  GER    Men
# 29212  Beijing  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas  LTU    Men
# 29213  Beijing  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri  ARM    Men
# 29214  Beijing  Wrestling  Wrestling Gre-R         LOPEZ, Mijain  CUB    Men
# 29215  Beijing  Wrestling  Wrestling Gre-R        BAROEV, Khasan  RUS    Men
#
# ...

# %%
olympic_data.select_dtypes(include='number')
# Out:
#        Edition
# 0         1896
# 1         1896
# 2         1896
# 3         1896
# 4         1896
# ...        ...
# 29211     2008
# 29212     2008
# 29213     2008
# 29214     2008
# 29215     2008
#
# [29216 rows x 1 columns]

# %% [markdown]
# ### Calculating the memory usage and changing data types of columns
# - We can find the memory usage (in bytes) of a Series or a DataFrame by using the memory_usage method. We include the deep parameter while using this method to get a more comprehensive picture of the memory usage at the system level.

# %%
olympic_data['NOC'].memory_usage(deep=True)
# Out:
# 1753088

# %%
olympic_data['NOC'].dtype #Series
# Out:
# dtype('O')

# %% [markdown]
# - As we can see, this column occupies 175308 bytes of memory and has a data type of “O”.
# - The Pandas categorical data type is useful for storing qualitative variables that have only a few unique values, as this reduces memory usage. Since the continent column has only a few unique values (“Europe”, “Asia”, “America”, “Africa”, “Oceania”), let us change the data type of this column from object to categorical, and see if this reduces memory usage.
# - We use the astype method for changing data types.

# %%
olympic_data['NOC']=olympic_data['NOC'].astype('category')  # type casting  object to category
olympic_data['NOC'].memory_usage(deep=True)
# Out:
# 71008

# %%
olympic_data.dtypes
# Out:
# City              object
# Edition            int64
# Sport             object
# Discipline        object
# Athlete           object
# NOC             category
# Gender            object
# Event             object
# Event_gender      object
# Medal             object
# dtype: object

# %%
olympic_data['NOC'].dtype
# Out:
# CategoricalDtype(categories=['AFG', 'AHO', 'ALG', 'ANZ', 'ARG', 'ARM', 'AUS', 'AUT',
#                   'AZE', 'BAH',
#                   ...
#                   'URS', 'URU', 'USA', 'UZB', 'VEN', 'VIE', 'YUG', 'ZAM',
#                   'ZIM', 'ZZX'],
# , ordered=False)

# %%
olympic_data.head(3)
# Out:
#      City  Edition     Sport Discipline            Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming      HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming   HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming  DRIVAS, Dimitrios  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze

# %% [markdown]
# - The memory usage seems to have reduced quite a bit after changing the data type. Let us calculate the exact percentage reduction.

# %%
(1753088-71008)/1753088
# Out:
# 0.9594954731308412

# %%
olympic_data['Medal'].memory_usage(deep=True)
# Out:
# 1821036

# %%
olympic_data['Medal']=olympic_data['Medal'].astype('category')

# %%
olympic_data['Medal'].memory_usage(deep=True)
# Out:
# 29639

# %%
olympic_data['Medal'].dtype
# Out:
# CategoricalDtype(categories=['Bronze', 'Gold', 'Silver'], ordered=False)

# %% [markdown]
# - A significant reduction in memory usage, around 95%, has been achieved by changing the data type from object to categorical.

# %% [markdown]
# ### Boolean indexing for selecting subsets of data
# - With Boolean indexing, we use conditional statements to filter data based on their values.
# - A single condition may be specified, or multiple conditions can be combined using the bitwise operators - & (and), | (or), ~ (not).
# - we select all records where the name of the continent is “Asia”, and the country name starts with the letter “C”.

# %%
url="https://raw.githubusercontent.com/svkarthik86/Advanced-python/main/subset-covid-data.csv"
covid_data=pd.read_csv(url)
covid_data.head(3)
# Out:
#        country continent        date  day  month  year  cases  deaths  \
# 0  Afghanistan      Asia  2020-04-12   12      4  2020     34       3
# 1      Albania    Europe  2020-04-12   12      4  2020     17       0
# 2      Algeria    Africa  2020-04-12   12      4  2020     64      19
#
#   country_code  population
# 0          AFG  37172386.0
# 1          ALB   2866376.0
# 2          DZA  42228429.0

# %% [markdown]
# Let us consider an example to understand this. Here, we select all records where the
# name of the continent is “Asia”, and the country name starts with the letter “C”

# %%
(covid_data['continent']=='Asia')
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 201    False
# 202     True
# 203     True
# 204    False
# 205    False
# Name: continent, Length: 206, dtype: bool

# %%
covid_data['country'].str.startswith('C')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 201    False
# 202    False
# 203    False
# 204    False
# 205    False
# Name: country, Length: 206, dtype: bool

# %%
covid_data[(covid_data['continent']=='Asia') & (covid_data['country'].str.startswith('C'))]
# Out:
#      country continent        date  day  month  year  cases  deaths  \
# 33  Cambodia      Asia  2020-04-12   12      4  2020      2       0
# 42     China      Asia  2020-04-12   12      4  2020     93       0
#
#    country_code    population
# 33          KHM  1.624980e+07
# 42          CHN  1.392730e+09

# %%
covid_data[(covid_data['cases']<=10) | (covid_data['continent']=='Asia')]
# Out:
#                  country continent        date  day  month  year  cases  \
# 0            Afghanistan      Asia  2020-04-12   12      4  2020     34
# 4                 Angola    Africa  2020-04-12   12      4  2020      0
# 5               Anguilla   America  2020-04-12   12      4  2020      0
# 6    Antigua_and_Barbuda   America  2020-04-12   12      4  2020      0
# 9                  Aruba   America  2020-04-12   12      4  2020      6
# ..                   ...       ...         ...  ...    ...   ...    ...
# 201            Venezuela   America  2020-04-12   12      4  2020      0
# 202              Vietnam      Asia  2020-04-12   12      4  2020      4
# 203                Yemen      Asia  2020-04-12   12      4  2020      0
# 204               Zambia    Africa  2020-04-12   12      4  2020      0
# 205             Zimbabwe    Africa  2020-04-12   12      4  2020      3
#
#      deaths country_code  population
# 0         3          AFG  37172386.0
# ...

# %% [markdown]
# ## Using the query method to retrieve data
# - While we combine multiple conditions as in the previous example, the readability of the code may suffer. The query method can be used in such cases.

# %% [markdown]
# Let us retrieve all the records where the name of the continent is “Asia” and the number
# of cases is higher than 500. Note the syntax where we enclose each condition within
# double quotes and use the logical and operator, instead of the bitwise operator, &.

# %%
covid_data.query("(continent=='Asia') and (cases>=500)")
# Out:
#     country continent        date  day  month  year  cases  deaths  \
# 91    India      Asia  2020-04-12   12      4  2020    909      34
# 93     Iran      Asia  2020-04-12   12      4  2020   1837     125
# 100   Japan      Asia  2020-04-12   12      4  2020   1401      10
# 190  Turkey      Asia  2020-04-12   12      4  2020   5138      95
#
#     country_code    population
# 91           IND  1.352617e+09
# 93           IRN  8.180027e+07
# 100          JPN  1.265291e+08
# 190          TUR  8.231972e+07

# %%
covid_data.query("cases<=1000 and country_code=='IND'")
# Out:
#    country continent        date  day  month  year  cases  deaths  \
# 91   India      Asia  2020-04-12   12      4  2020    909      34
#
#    country_code    population
# 91          IND  1.352617e+09

# %% [markdown]
# ### Further reading
# - See more on:
# - • Query method: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.query.html
# - • Indexing in Pandas: https://pandas.pydata.org/docs/user_guide/indexing.html

# %% [markdown]
# ### Operators in Pandas
# - Pandas uses the following operators that can be applied to a whole series. While Python would require a loop to iterate through every element in a list or dictionary, Pandas takes advantage of the feature of vectorization implemented in NumPy that enables these operators to be applied on every element in a sequence, eliminating the need for iteration and loops.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
covid_data.head(2)
# Out:
#        country continent        date  day  month  year  cases  deaths  \
# 0  Afghanistan      Asia  2020-04-12   12      4  2020     34       3
# 1      Albania    Europe  2020-04-12   12      4  2020     17       0
#
#   country_code  population
# 0          AFG  37172386.0
# 1          ALB   2866376.0

# %%
covid_data['Live']=covid_data['cases']-covid_data['deaths']

# %%
covid_data.head(2)
# Out:
#        country continent        date  day  month  year  cases  deaths  \
# 0  Afghanistan      Asia  2020-04-12   12      4  2020     34       3
# 1      Albania    Europe  2020-04-12   12      4  2020     17       0
#
#   country_code  population  Live
# 0          AFG  37172386.0    31
# 1          ALB   2866376.0    17

# %% [markdown]
# # Basic Data Analysis

# %% [markdown]
# ## using value_counts

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
olympic_data=pd.read_csv("https://raw.githubusercontent.com/svkarthik86/Advance-Python-Numpy/main/olympics.csv",skiprows=4)
olympic_data.head(3)
# Out:
#      City  Edition     Sport Discipline            Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming      HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming   HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming  DRIVAS, Dimitrios  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze

# %%
olympic_data.Event.value_counts(ascending=False,dropna=0)
# Out:
# football                          1387
# hockey                            1325
# team competition                  1018
# basketball                         940
# eight with coxswain (8+)           918
#                                   ...
# 8m class C                           2
# - 47.63kg (flyweight)                2
# 47.63 - 52.16kg (bantamweight)       2
# 65.77 - 71.67kg (middleweight)       2
# open class A                         1
# Name: Event, Length: 577, dtype: int64

# %%
olympic_data['Edition'].value_counts(ascending=True,dropna=0)
# Out:
# 1896     151
# 1904     470
# 1900     512
# 1932     615
# 1928     710
# 1908     804
# 1948     814
# 1936     875
# 1960     882
# 1924     884
# 1956     885
# 1912     885
# 1952     889
# 1964    1010
# 1968    1031
# 1972    1185
# 1920    1298
# 1976    1305
# 1980    1387
# 1984    1459
# 1988    1546
# 1992    1705
# 1996    1859
# 2004    1998
# 2000    2015
# 2008    2042
# Name: Edition, dtype: int64

# %%
olympic_data['City'].value_counts(ascending=False).head(4)
# Out:
# Athens         2149
# Los Angeles    2074
# Beijing        2042
# Sydney         2015
# Name: City, dtype: int64

# %%
olympic_data.Gender.value_counts(dropna=True)  # how many medals were awarded to men and women
# Out:
# Men      21721
# Women     7495
# Name: Gender, dtype: int64

# %% [markdown]
# ## Using  sort_values()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
covid_data.isna()
# Out:
#      country  continent   date    day  month   year  cases  deaths  \
# 0      False      False  False  False  False  False  False   False
# 1      False      False  False  False  False  False  False   False
# 2      False      False  False  False  False  False  False   False
# 3      False      False  False  False  False  False  False   False
# 4      False      False  False  False  False  False  False   False
# ..       ...        ...    ...    ...    ...    ...    ...     ...
# 201    False      False  False  False  False  False  False   False
# 202    False      False  False  False  False  False  False   False
# 203    False      False  False  False  False  False  False   False
# 204    False      False  False  False  False  False  False   False
# 205    False      False  False  False  False  False  False   False
#
#      country_code  population   Live
# 0           False       False  False
# 1           False       False  False
# 2           False       False  False
# ...

# %%
any(covid_data.isna())
# Out:
# True

# %%
covid_data.isna().any(axis=1)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 201    False
# 202    False
# 203    False
# 204    False
# 205    False
# Length: 206, dtype: bool

# %%
covid_data[covid_data.isna().any(axis=1)] # find all nan values
# Out:
#                                        country continent        date  day  \
# 5                                     Anguilla   America  2020-04-12   12
# 24           Bonaire, Saint Eustatius and Saba   America  2020-04-12   12
# 37  Cases_on_an_international_conveyance_Japan     Other  2020-01-18   18
# 61                                     Eritrea    Africa  2020-04-12   12
# 65                 Falkland_Islands_(Malvinas)   America  2020-04-12   12
#
#     month  year  cases  deaths country_code  population  Live
# 5       4  2020      0       0          NaN         NaN     0
# 24      4  2020      0       0          NaN         NaN     0
# 37      1  2020      0       0          NaN      3000.0     0
# 61      4  2020      0       0          ERI         NaN     0
# 65      4  2020      0       0          NaN         NaN     0

# %%
covid_data.country_code.sort_values(ascending=True,na_position='last')
# Out:
# 9      ABW
# 0      AFG
# 4      AGO
# 1      ALB
# 3      AND
#       ...
# 205    ZWE
# 5      NaN
# 24     NaN
# 37     NaN
# 65     NaN
# Name: country_code, Length: 206, dtype: object

# %%
olympic_data.Athlete.sort_values(ascending=True,na_position='first')
# Out:
# 651                 AABYE, Edgar
# 2849       AALTONEN, Arvo Ossian
# 2852       AALTONEN, Arvo Ossian
# 7716    AALTONEN, Paavo Johannes
# 7730    AALTONEN, Paavo Johannes
#                   ...
# 603                   ÖSTMO, Ole
# 608                   ÖSTMO, Ole
# 621                   ÖSTMO, Ole
# 596                   ÖSTMO, Ole
# 8051           ÖSTRAND, Per-Olof
# Name: Athlete, Length: 29216, dtype: object

# %%
olympic_data.Sport.sort_values(na_position='first')
# Out:
# 0         Aquatics
# 7221      Aquatics
# 7220      Aquatics
# 7219      Aquatics
# 7218      Aquatics
#            ...
# 18033    Wrestling
# 18034    Wrestling
# 18035    Wrestling
# 8905     Wrestling
# 29215    Wrestling
# Name: Sport, Length: 29216, dtype: object

# %%
olympic_data.Edition.sort_values(ascending=False,na_position='first')
# Out:
# 29215    2008
# 27859    2008
# 27846    2008
# 27847    2008
# 27848    2008
#          ...
# 101      1896
# 100      1896
# 99       1896
# 98       1896
# 0        1896
# Name: Edition, Length: 29216, dtype: int64

# %%
olympic_data
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 0       Athens     1896   Aquatics         Swimming         HAJOS, Alfred
# 1       Athens     1896   Aquatics         Swimming      HERSCHMANN, Otto
# 2       Athens     1896   Aquatics         Swimming     DRIVAS, Dimitrios
# 3       Athens     1896   Aquatics         Swimming    MALOKINIS, Ioannis
# 4       Athens     1896   Aquatics         Swimming    CHASAPIS, Spiridon
# ...        ...      ...        ...              ...                   ...
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender                       Event Event_gender   Medal
# ...

# %%
olympic_data.sort_values(by=['Edition','Athlete','NOC'], ascending=False)
# Out:
#           City  Edition       Sport    Discipline  \
# 29007  Beijing     2008      Tennis        Tennis
# 28387  Beijing     2008  Gymnastics   Rhythmic G.
# 28977  Beijing     2008   Taekwondo     Taekwondo
# 28819  Beijing     2008     Sailing       Sailing
# 28095  Beijing     2008  Equestrian      Dressage
# ...        ...      ...         ...           ...
# 48      Athens     1896     Cycling  Cycling Road
# 111     Athens     1896  Gymnastics   Artistic G.
# 82      Athens     1896  Gymnastics   Artistic G.
# 110     Athens     1896  Gymnastics   Artistic G.
# 7       Athens     1896    Aquatics      Swimming
#
#                               Athlete  NOC Gender                 Event  \
# 29007                 ZVONAREVA, Vera  RUS  Women               singles
# 28387                  ZUEVA, Natalia  RUS  Women     group competition
# 28977                 ZUBCIC, Martina  CRO  Women            49 - 57 kg
# ...

# %% [markdown]
# # Using Boolean Indexing

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# determine which athlete have won the gold medal
olympic_data[olympic_data.Medal=='Gold'].loc[:,['Athlete','Sport',"Medal"]]     #[['Athlete','Sport']]
# Out:
#                    Athlete      Sport Medal
# 0            HAJOS, Alfred   Aquatics  Gold
# 3       MALOKINIS, Ioannis   Aquatics  Gold
# 6            HAJOS, Alfred   Aquatics  Gold
# 9            NEUMANN, Paul   Aquatics  Gold
# 13           BURKE, Thomas  Athletics  Gold
# ...                    ...        ...   ...
# 29199       GUENOT, Steeve  Wrestling  Gold
# 29203  KVIRKELIA, Manuchar  Wrestling  Gold
# 29206     MINGUZZI, Andrea  Wrestling  Gold
# 29210   KHUSHTOV, Aslanbek  Wrestling  Gold
# 29214        LOPEZ, Mijain  Wrestling  Gold
#
# [9850 rows x 3 columns]

# %%
olympic_data.query("(Medal=='Gold')").loc[:,['Athlete','Sport',"Medal"]]     #[['Athlete','Sport']]
# Out:
#                    Athlete      Sport Medal
# 0            HAJOS, Alfred   Aquatics  Gold
# 3       MALOKINIS, Ioannis   Aquatics  Gold
# 6            HAJOS, Alfred   Aquatics  Gold
# 9            NEUMANN, Paul   Aquatics  Gold
# 13           BURKE, Thomas  Athletics  Gold
# ...                    ...        ...   ...
# 29199       GUENOT, Steeve  Wrestling  Gold
# 29203  KVIRKELIA, Manuchar  Wrestling  Gold
# 29206     MINGUZZI, Andrea  Wrestling  Gold
# 29210   KHUSHTOV, Aslanbek  Wrestling  Gold
# 29214        LOPEZ, Mijain  Wrestling  Gold
#
# [9850 rows x 3 columns]

# %%
#gold medals with women 
#odata[(odata.Medal=='Gold')&(odata.Gender=="Women")&(odata.Edition==2008)].sort_values(by=['Athlete'],ascending=1)
olympic_data.query("(Medal=='Gold') and (Gender=='Women') and (Edition==2008)").sort_values(by=['Athlete'],ascending=1)
# Out:
#           City  Edition         Sport    Discipline                Athlete  \
# 28460  Beijing     2008      Handball      Handball       AAMODT, Ragnhild
# 27273  Beijing     2008      Aquatics      Swimming     ADLINGTON, Rebecca
# 27402  Beijing     2008      Aquatics      Swimming     ADLINGTON, Rebecca
# 28554  Beijing     2008        Hockey        Hockey      AGLIOTTI, Marilyn
# 29076  Beijing     2008    Volleyball    Volleyball  ALBUQUERQUE, Carolina
# ...        ...      ...           ...           ...                    ...
# 28781  Beijing     2008        Rowing        Rowing        ZHANG, Yangyang
# 28940  Beijing     2008  Table Tennis  Table Tennis          ZHANG, Yining
# 28956  Beijing     2008  Table Tennis  Table Tennis          ZHANG, Yining
# 28191  Beijing     2008       Fencing       Fencing          ZHOVNIR, Olha
# 28387  Beijing     2008    Gymnastics   Rhythmic G.         ZUEVA, Natalia
#
# ...

# %% [markdown]
# # Using String Handling

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
olympic_data[olympic_data.Athlete.str.contains("Alfred")]
# Out:
#           City  Edition       Sport   Discipline                   Athlete  \
# 0       Athens     1896    Aquatics     Swimming             HAJOS, Alfred
# 6       Athens     1896    Aquatics     Swimming             HAJOS, Alfred
# 73      Athens     1896  Gymnastics  Artistic G.            FLATOW, Alfred
# 74      Athens     1896  Gymnastics  Artistic G.            FLATOW, Alfred
# 85      Athens     1896  Gymnastics  Artistic G.            FLATOW, Alfred
# ...        ...      ...         ...          ...                       ...
# 24130   Sydney     2000     Fencing      Fencing             ROTA, Alfredo
# 27656  Beijing     2008   Athletics    Athletics        YEGO, Alfred Kirwa
# 27796  Beijing     2008    Baseball     Baseball        DESPAIGNE, Alfredo
# 27828  Beijing     2008  Basketball   Basketball  QUINTEROS, Alfredo Paolo
# 28142  Beijing     2008     Fencing      Fencing             ROTA, Alfredo
#
#        NOC Gender                 Event Event_gender   Medal
# ...

# %%
olympic_data[olympic_data.Event.str.startswith('84')]
# Out:
#           City  Edition      Sport       Discipline                 Athlete  \
# 27147   Athens     2004  Wrestling  Wrestling Free.        HEIDARI, Alireza
# 27148   Athens     2004  Wrestling  Wrestling Free.  GATSALOV, Khadjimourat
# 27149   Athens     2004  Wrestling  Wrestling Free.      IBRAGIMOV, Magomed
# 27168   Athens     2004  Wrestling  Wrestling Gre-R            OZAL, Mehmet
# 27169   Athens     2004  Wrestling  Wrestling Gre-R    GABER IBRAHIM, Karam
# 27170   Athens     2004  Wrestling  Wrestling Gre-R          NOZADZE, Ramaz
# 29181  Beijing     2008  Wrestling  Wrestling Free.        GAZYUMOV, Khetag
# 29182  Beijing     2008  Wrestling  Wrestling Free.     GOGSHELIDZE, George
# 29183  Beijing     2008  Wrestling  Wrestling Free.       MURADOV, Shirvani
# 29184  Beijing     2008  Wrestling  Wrestling Free.       TIGIYEV, Taimuraz
# 29208  Beijing     2008  Wrestling  Wrestling Gre-R         MAMBETOV, Asset
# ...

# %%
olympic_data[olympic_data.Event.str.isnumeric()]
# Out:
# Empty DataFrame
# Columns: [City, Edition, Sport, Discipline, Athlete, NOC, Gender, Event, Event_gender, Medal]
# Index: []

# %%
olympic_data[olympic_data.Event.str.startswith('4')]
# Out:
#           City  Edition          Sport       Discipline  \
# 8       Athens     1896       Aquatics         Swimming
# 9       Athens     1896       Aquatics         Swimming
# 10      Athens     1896       Aquatics         Swimming
# 20      Athens     1896      Athletics        Athletics
# 21      Athens     1896      Athletics        Athletics
# ...        ...      ...            ...              ...
# 29114  Beijing     2008  Weightlifting    Weightlifting
# 29153  Beijing     2008      Wrestling  Wrestling Free.
# 29154  Beijing     2008      Wrestling  Wrestling Free.
# 29155  Beijing     2008      Wrestling  Wrestling Free.
# 29156  Beijing     2008      Wrestling  Wrestling Free.
#
#                      Athlete  NOC Gender           Event Event_gender   Medal
# 8      CHOROPHAS, Efstathios  GRE    Men  400m freestyle            M  Bronze
# 9              NEUMANN, Paul  AUT    Men  400m freestyle            M    Gold
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Lab Exercise problems:

# %% [markdown]
# Problem on Olympic_data
# 1.In which events did Jesse Owens win a medal?
#
# 2.Which country has won the most men's gold medals in singles badminton over the years?
#   Sort the results alphabetically by the player's names.
#
# 3.Which three countries have won the most medals in recent years (from 1984 to 2008)?
#
# 4.Display the male gold medal winners for the 100m Track & Field sprint event over the years.
#   List the results starting with the most recent. Show the Olympic City, Edition, Athlete and the country they represent.

# %% [markdown]
# ## 1.In which events did Jesse Owens win a medal?

# %%
import pandas as pd
olympic_data=pd.read_csv("https://raw.githubusercontent.com/svkarthik86/Advance-Python-Numpy/main/olympics.csv",skiprows=4)
olympic_data.head(3)
# Out:
#      City  Edition     Sport Discipline            Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming      HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming   HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming  DRIVAS, Dimitrios  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze

# %%
olympic_data[olympic_data["Athlete"].str.contains("Jesse")]
# Out:
#                         City  Edition       Sport     Discipline  \
# 1522                  London     1908      Hockey         Hockey
# 1773                  London     1908    Shooting       Shooting
# 6427                  Berlin     1936   Athletics      Athletics
# 6439                  Berlin     1936   Athletics      Athletics
# 6456                  Berlin     1936   Athletics      Athletics
# 6523                  Berlin     1936   Athletics      Athletics
# 7444                  London     1948  Basketball     Basketball
# 9070   Melbourne / Stockholm     1956   Athletics      Athletics
# 11462                  Tokyo     1964      Rowing         Rowing
# 13113                 Munich     1972      Boxing         Boxing
# 26519                 Athens     2004      Hockey         Hockey
# 27479                Beijing     2008    Aquatics     Water polo
# 28065                Beijing     2008     Cycling  Cycling Track
#
# ...

# %%
olympic_data[olympic_data["Athlete"]=="OWENS, Jesse"].Event.values
# Out:
# array(['100m', '200m', '4x100m relay', 'long jump'], dtype=object)

# %%
olympic_data[olympic_data["Athlete"].str.contains("OWENS, Jesse")].Event.value_counts()
# Out:
# 100m            1
# 200m            1
# 4x100m relay    1
# long jump       1
# Name: Event, dtype: int64

# %%
#m2
olympic_data.query("Athlete.str.contains('OWENS, Jesse')").Event.value_counts()
# Out:
# 100m            1
# 200m            1
# 4x100m relay    1
# long jump       1
# Name: Event, dtype: int64

# %% [markdown]
# ### 2.Which country has won the most men's gold medals in singles badminton over the years? Sort the results alphabetically by the player's  names.

# %%
gbm=olympic_data[(olympic_data.Medal=='Gold') & (olympic_data.Gender=='Men')&(olympic_data.Sport=='Badminton')]
gbm.sort_values(by='Athlete')
# Out:
#             City  Edition      Sport Discipline                  Athlete  NOC  \
# 20045  Barcelona     1992  Badminton  Badminton        BUDI KUSUMA, Alan  INA
# 23701     Sydney     2000  Badminton  Badminton            GUNAWAN, Tony  INA
# 25718     Athens     2004  Badminton  Badminton             HA, Tae-Kwon  KOR
# 25734     Athens     2004  Badminton  Badminton          HIDAYAT, Taufik  INA
# 21787    Atlanta     1996  Badminton  Badminton  HOYER-LARSEN, Poul Erik  DEN
# 23717     Sydney     2000  Badminton  Badminton              JI, Xinpeng  CHN
# 27725    Beijing     2008  Badminton  Badminton             KIDO, Markis  INA
# 25719     Athens     2004  Badminton  Badminton           KIM, Dong Moon  KOR
# 21773    Atlanta     1996  Badminton  Badminton           KIM, Dong Moon  KOR
# 20031  Barcelona     1992  Badminton  Badminton            KIM, Moon-Soo  KOR
# 27727    Beijing     2008  Badminton  Badminton             LEE, Yongdae  KOR
# ...

# %%
gbm[gbm.sort_values(by='Athlete').Event.str.contains("singles")]
# Out:
# C:\Users\karthick\AppData\Local\Temp\ipykernel_18928\2490351285.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   gbm[gbm.sort_values(by='Athlete').Event.str.contains("singles")]
#             City  Edition      Sport Discipline                  Athlete  NOC  \
# 20045  Barcelona     1992  Badminton  Badminton        BUDI KUSUMA, Alan  INA
# 21787    Atlanta     1996  Badminton  Badminton  HOYER-LARSEN, Poul Erik  DEN
# 23717     Sydney     2000  Badminton  Badminton              JI, Xinpeng  CHN
# 25734     Athens     2004  Badminton  Badminton          HIDAYAT, Taufik  INA
# 27741    Beijing     2008  Badminton  Badminton                 LIN, Dan  CHN
#
#       Gender    Event Event_gender Medal
# 20045    Men  singles            M  Gold
# 21787    Men  singles            M  Gold
# 23717    Men  singles            M  Gold
# 25734    Men  singles            M  Gold
# 27741    Men  singles            M  Gold

# %%
gbm2=olympic_data.query("(Medal=='Gold')and(Gender=='Men')and(Sport=='Badminton')")
gbm2[gbm2.Event.str.contains("singles")].sort_values(by='Athlete')
# Out:
#             City  Edition      Sport Discipline                  Athlete  NOC  \
# 20045  Barcelona     1992  Badminton  Badminton        BUDI KUSUMA, Alan  INA
# 25734     Athens     2004  Badminton  Badminton          HIDAYAT, Taufik  INA
# 21787    Atlanta     1996  Badminton  Badminton  HOYER-LARSEN, Poul Erik  DEN
# 23717     Sydney     2000  Badminton  Badminton              JI, Xinpeng  CHN
# 27741    Beijing     2008  Badminton  Badminton                 LIN, Dan  CHN
#
#       Gender    Event Event_gender Medal
# 20045    Men  singles            M  Gold
# 25734    Men  singles            M  Gold
# 21787    Men  singles            M  Gold
# 23717    Men  singles            M  Gold
# 27741    Men  singles            M  Gold

# %% [markdown]
# ### 3.Which three countries have won the most medals in recent years (from 1984 to 2008)?

# %%
rcy=olympic_data[olympic_data.Edition>=1984]

# %%
rcy
# Out:
#               City  Edition      Sport       Discipline  \
# 16592  Los Angeles     1984   Aquatics           Diving
# 16593  Los Angeles     1984   Aquatics           Diving
# 16594  Los Angeles     1984   Aquatics           Diving
# 16595  Los Angeles     1984   Aquatics           Diving
# 16596  Los Angeles     1984   Aquatics           Diving
# ...            ...      ...        ...              ...
# 29211      Beijing     2008  Wrestling  Wrestling Gre-R
# 29212      Beijing     2008  Wrestling  Wrestling Gre-R
# 29213      Beijing     2008  Wrestling  Wrestling Gre-R
# 29214      Beijing     2008  Wrestling  Wrestling Gre-R
# 29215      Beijing     2008  Wrestling  Wrestling Gre-R
#
#                            Athlete  NOC Gender         Event Event_gender  \
# 16592               LI, Kong-Zheng  CHN    Men  10m platform            M
# 16593            LOUGANIS, Gregory  USA    Men  10m platform            M
# ...

# %%
rcy.NOC.value_counts().head(3)
# Out:
# USA    1837
# AUS     762
# GER     691
# Name: NOC, dtype: int64

# %% [markdown]
# ### 4.Display the male gold medal winners for the 100m Track & Field sprint event over the years. List the results starting with the most recent. Show the Olympic City, Edition, Athlete and the country they represent.

# %%
gmh=olympic_data.query("(Medal=='Gold')and(Gender=='Men')and(Event=='100m')")

# %%
gmh.sort_values(by=['Edition'],ascending=0).loc[:,['City','Edition','Athlete','NOC']]#filter(['City','Edition','Athlete','NOC'],axis=1)
# Out:
#                         City  Edition                Athlete  NOC
# 27552                Beijing     2008            BOLT, Usain  JAM
# 25539                 Athens     2004         GATLIN, Justin  USA
# 23521                 Sydney     2000        GREENE, Maurice  USA
# 21598                Atlanta     1996        BAILEY, Donovan  CAN
# 19859              Barcelona     1992      CHRISTIE, Linford  GBR
# 18284                  Seoul     1988            LEWIS, Carl  USA
# 16794            Los Angeles     1984            LEWIS, Carl  USA
# 15374                 Moscow     1980           WELLS, Allan  GBR
# 14069               Montreal     1976       CRAWFORD, Hasely  TRI
# 12902                 Munich     1972         BORZOV, Valery  URS
# 11865                 Mexico     1968       HINES, James Ray  USA
# 10823                  Tokyo     1964          HAYES, Robert  USA
# 9924                    Rome     1960            HARY, Armin  EUA
# ...

# %%
olympic_data.head(2)
# Out:
#      City  Edition     Sport Discipline           Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming     HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming  HERSCHMANN, Otto  AUT    Men
#
#             Event Event_gender   Medal
# 0  100m freestyle            M    Gold
# 1  100m freestyle            M  Silver

# %%
olympic_data.filter(items=[1,10,45],axis=0)
# Out:
#       City  Edition      Sport Discipline            Athlete  NOC Gender  \
# 1   Athens     1896   Aquatics   Swimming   HERSCHMANN, Otto  AUT    Men
# 10  Athens     1896   Aquatics   Swimming  PEPANOS, Antonios  GRE    Men
# 45  Athens     1896  Athletics  Athletics  PERSAKIS, Ioannis  GRE    Men
#
#              Event Event_gender   Medal
# 1   100m freestyle            M  Silver
# 10  400m freestyle            M  Silver
# 45     triple jump            M  Bronze

# %%
olympic_data.columns
# Out:
# Index(['City', 'Edition', 'Sport', 'Discipline', 'Athlete', 'NOC', 'Gender',
#        'Event', 'Event_gender', 'Medal'],
#       dtype='object')

# %% [markdown]
# # Data Grouping, Aggregation, and Merging with Pandas

# %% [markdown]
# ### groupby method,

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Aggregation is the process of summarizing a group of values into a single value.
# - 1.Split the data into smaller groups that are manageable and independent of each other. This is done using the groupby method in Pandas.
# - 2.Apply functions on each of these groups. We can apply any of the aggregation functions, including minimum, maximum, median, mean, sum, count, standard deviation, variance, and size.
# Each of these aggregate functions calculate the aggregate value of the entire group. Note that we can also write a customized aggregation function.
# - 3.Combine the results after applying functions to each group into a single combined object.

# %% [markdown]
# - In the following section, we look at the groupby method, aggregation functions, the transform, filter, and apply methods, and the properties of the groupby object.

# %%
url="https://raw.githubusercontent.com/svkarthik86/Advanced-python/main/subset-covid-data.csv"
covid_data=pd.read_csv(url)
covid_data.head(3)
# Out:
#        country continent        date  day  month  year  cases  deaths  \
# 0  Afghanistan      Asia  2020-04-12   12      4  2020     34       3
# 1      Albania    Europe  2020-04-12   12      4  2020     17       0
# 2      Algeria    Africa  2020-04-12   12      4  2020     64      19
#
#   country_code  population
# 0          AFG  37172386.0
# 1          ALB   2866376.0
# 2          DZA  42228429.0

# %%
covid_data.continent.unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'America', 'Oceania', 'Other'],
#       dtype=object)

# %%
go=covid_data.groupby('continent')

# %%
go

# %%
type(go)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
list(go)[5][1]
# Out:
#                                        country continent        date  day  \
# 37  Cases_on_an_international_conveyance_Japan     Other  2020-01-18   18
#
#     month  year  cases  deaths country_code  population
# 37      1  2020      0       0          NaN      3000.0

# %%
for key,df_value in go:
    print(key)
# Out:
# Africa
# America
# Asia
# Europe
# Oceania
# Other

# %% [markdown]
# # Examining the properties of the groupby object

# %%
go=covid_data.groupby('continent')

# %% [markdown]
# ### Data type of groupby object

# %%
type(go)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %% [markdown]
# ## Obtaining the names of the groups
# - The groupby object has an attribute called groups. Using this attribute on the groupby object would return a dictionary, with the keys of this dictionary being the names of the groups.

# %%
go.groups.keys()
# Out:
# dict_keys(['Africa', 'America', 'Asia', 'Europe', 'Oceania', 'Other'])

# %% [markdown]
# ### Returning records with the same position in each group using the nth method
# - Let us say that you want to see the details of the fourth country belonging to each continent. Using the nth method, we can retrieve this data by using a positional index value of 3 for the fourth position.

# %%
go.nth(0)
# Out:
#                                               country        date  day  month  \
# continent
# Africa                                        Algeria  2020-04-12   12      4
# America                                      Anguilla  2020-04-12   12      4
# Asia                                      Afghanistan  2020-04-12   12      4
# Europe                                        Albania  2020-04-12   12      4
# Oceania                                     Australia  2020-04-12   12      4
# Other      Cases_on_an_international_conveyance_Japan  2020-01-18   18      1
#
#            year  cases  deaths country_code  population
# continent
# Africa     2020     64      19          DZA  42228429.0
# America    2020      0       0          NaN         NaN
# Asia       2020     34       3          AFG  37172386.0
# Europe     2020     17       0          ALB   2866376.0
# Oceania    2020     51       3          AUS  24992369.0
# Other      2020      0       0          NaN      3000.0

# %% [markdown]
# ## noumber of Groups

# %%
go.ngroups
# Out:
# 6

# %%
#each Group size

# %%
go.size()
# Out:
# continent
# Africa     52
# America    49
# Asia       42
# Europe     54
# Oceania     8
# Other       1
# dtype: int64

# %%
#index of Group object

# %%
go.groups['Africa']
# Out:
# Int64Index([  2,   4,  20,  26,  31,  32,  34,  36,  39,  40,  44,  46,  52,
#              54,  58,  60,  61,  63,  64,  71,  72,  75,  83,  84, 104, 111,
#             112, 116, 117, 120, 122, 123, 130, 131, 133, 139, 140, 158, 163,
#             165, 167, 168, 173, 174, 176, 179, 187, 189, 192, 196, 204, 205],
#            dtype='int64')

# %% [markdown]
# ## Get all the data for a particular group using the get_group method
# - Use the get_group method with the name of the group as an argument to this method. In this example, we retrieve all data for the group named ‘Europe’.

# %%
go.get_group('America')
# Out:
#                                country continent        date  day  month  \
# 5                             Anguilla   America  2020-04-12   12      4
# 6                  Antigua_and_Barbuda   America  2020-04-12   12      4
# 7                            Argentina   America  2020-04-12   12      4
# 9                                Aruba   America  2020-04-12   12      4
# 13                             Bahamas   America  2020-04-12   12      4
# 16                            Barbados   America  2020-04-12   12      4
# 19                              Belize   America  2020-04-12   12      4
# 21                             Bermuda   America  2020-04-12   12      4
# 23                             Bolivia   America  2020-04-12   12      4
# 24   Bonaire, Saint Eustatius and Saba   America  2020-04-12   12      4
# 27                              Brazil   America  2020-04-12   12      4
# 28              British_Virgin_Islands   America  2020-04-12   12      4
# ...

# %% [markdown]
# ## get the first or last record from each group using the first() and last() functions

# %%
go.first()
# Out:
#                                               country        date  day  month  \
# continent
# Africa                                        Algeria  2020-04-12   12      4
# America                                      Anguilla  2020-04-12   12      4
# Asia                                      Afghanistan  2020-04-12   12      4
# Europe                                        Albania  2020-04-12   12      4
# Oceania                                     Australia  2020-04-12   12      4
# Other      Cases_on_an_international_conveyance_Japan  2020-01-18   18      1
#
#            year  cases  deaths country_code  population
# continent
# Africa     2020     64      19          DZA  42228429.0
# America    2020      0       0          ATG     96286.0
# Asia       2020     34       3          AFG  37172386.0
# Europe     2020     17       0          ALB   2866376.0
# Oceania    2020     51       3          AUS  24992369.0
# Other      2020      0       0         None      3000.0

# %%
go.last()
# Out:
#                                               country        date  day  month  \
# continent
# Africa                                       Zimbabwe  2020-04-12   12      4
# America                                     Venezuela  2020-04-12   12      4
# Asia                                            Yemen  2020-04-12   12      4
# Europe                                 United_Kingdom  2020-04-12   12      4
# Oceania                              Papua_New_Guinea  2020-04-12   12      4
# Other      Cases_on_an_international_conveyance_Japan  2020-01-18   18      1
#
#            year  cases  deaths country_code  population
# continent
# Africa     2020      3       0          ZWE  14439018.0
# America    2020      0       0          VEN  28870195.0
# Asia       2020      0       0          YEM  28498687.0
# Europe     2020   8719     839          GBR  66488991.0
# Oceania    2020      0       0          PNG   8606316.0
# Other      2020      0       0         None      3000.0

# %%
go.groups.keys()
# Out:
# dict_keys(['Africa', 'America', 'Asia', 'Europe', 'Oceania', 'Other'])

# %%
covid_data.groupby(by=['continent'])[['cases','deaths']].sum()
# Out:
#            cases  deaths
# continent
# Africa       714      52
# America    33519    2111
# Asia       12979     383
# Europe     34141    3571
# Oceania       68       4
# Other          0       0

# %% [markdown]
# # aggregate

# %% [markdown]
# As we can see, there are several countries belonging to the same continent. Let us find
# the total number of cases and deaths for each continent. For this, we need to do grouping
# using the ‘continent’ column.

# %%
covid_data.groupby('continent')[['cases','deaths']].sum()
# Out:
#            cases  deaths
# continent
# Africa       714      52
# America    33519    2111
# Asia       12979     383
# Europe     34141    3571
# Oceania       68       4
# Other          0       0

# %% [markdown]
# ## aggregating function

# %% [markdown]
# Whenever you perform a groupby operation, it is recommended that these three elements (grouping column, aggregating column, and aggregating function) be identified at the outset.

# %% [markdown]
# - The following thirteen aggregate functions can be applied to groups: sum(), max(), min(), std(), var(), mean(), count(), size(), sem(), first(), last(), describe(), nth().
#
# - We can also use the agg method, with np.sum as an attribute, which produces the same output as the previous statement:

# %%
import numpy as np
covid_data.groupby('continent')[['cases','deaths']].agg(np.sum)
# Out:
#            cases  deaths
# continent
# Africa       714      52
# America    33519    2111
# Asia       12979     383
# Europe     34141    3571
# Oceania       68       4
# Other          0       0

# %%
go.agg()

# %%
covid_data.groupby('continent')[['cases','deaths']].agg([np.sum,np.max,np.var])
# Out:
#            cases                      deaths
#              sum   amax           var    sum  amax           var
# continent
# Africa       714    145  7.349849e+02     52    19      9.411765
# America    33519  28391  1.639756e+07   2111  1831  68250.201531
# Asia       12979   5138  7.210580e+05    383   125    614.009872
# Europe     34141   8719  2.331395e+06   3571   839  33339.284766
# Oceania       68     51  3.182857e+02      4     3      1.142857
# Other          0      0           NaN      0     0           NaN

# %%
covid_data.groupby('continent').agg({'cases':[np.sum,np.max,np.var],'day':[max,min]}) # dict parameter
# Out:
#            cases                      day
#              sum   amax           var max min
# continent
# Africa       714    145  7.349849e+02  12  12
# America    33519  28391  1.639756e+07  12  12
# Asia       12979   5138  7.210580e+05  12  12
# Europe     34141   8719  2.331395e+06  12  11
# Oceania       68     51  3.182857e+02  12  12
# Other          0      0           NaN  18  18

# %% [markdown]
# ### Filtering groups
# - The filter method removes or filters out groups based on a particular condition.
# - While the agg (aggregate) method returns one value for each group, the filter method returns records from each group depending on whether the condition is satisfied.

# %% [markdown]
# - Let us consider an example to understand this.
# - We want to return all the rows for the continents where the average death rate is greater than 40.
# - The filter method is called on a groupby object and the argument to the filter method is a lambda function or a predefined function.
# - The lambda function here calculates the average death rate for every group, represented by the argument “x”.
# - This argument is a DataFrame representing each group (which is the continent in our example).
# - If the condition is satisfied for the group, all its rows are returned. Otherwise, all the rows of the group are excluded.

# %%
covid_data['deaths'].mean()
# Out:
# 29.71359223300971

# %%
grouped_continents.get_group('America')[["deaths"]].mean()
# Out:
# deaths    43.081633
# dtype: float64

# %%
grouped_continents.get_group('Asia')[["deaths"]].mean()
# Out:
# deaths    9.119048
# dtype: float64

# %%
grouped_continents.get_group('Europe')[["deaths"]].mean()
# Out:
# deaths    66.12963
# dtype: float64

# %%
grouped_continents=covid_data.groupby('continent')
grouped_continents.filter(lambda x:x['deaths'].mean()>=40)
# Out:
#                           country continent        date  day  month  year  \
# 1                         Albania    Europe  2020-04-12   12      4  2020
# 3                         Andorra    Europe  2020-04-12   12      4  2020
# 5                        Anguilla   America  2020-04-12   12      4  2020
# 6             Antigua_and_Barbuda   America  2020-04-12   12      4  2020
# 7                       Argentina   America  2020-04-12   12      4  2020
# ..                            ...       ...         ...  ...    ...   ...
# 195                United_Kingdom    Europe  2020-04-12   12      4  2020
# 197  United_States_Virgin_Islands   America  2020-04-12   12      4  2020
# 198      United_States_of_America   America  2020-04-12   12      4  2020
# 199                       Uruguay   America  2020-04-12   12      4  2020
# 201                     Venezuela   America  2020-04-12   12      4  2020
#
#      cases  deaths country_code   population
# ...

# %% [markdown]
# # Dealing with missing data
# - Missing data in Pandas is represented by the value NaN (Not a Number), denoted as the keyword np.nan.
# - We can use the isna or isnull method for finding null values.
# - Both methods return a True (for a missing value) or False (for all other values) Boolean value for each object in the Series or DataFrame.

# %%
import numpy as np
import pandas as pd
url="https://raw.githubusercontent.com/svkarthik86/Advanced-python/main/subset-covid-data.csv"
covid_data=pd.read_csv(url)
covid_data.head(3)
# Out:
#        country continent        date  day  month  year  cases  deaths  \
# 0  Afghanistan      Asia  2020-04-12   12      4  2020     34       3
# 1      Albania    Europe  2020-04-12   12      4  2020     17       0
# 2      Algeria    Africa  2020-04-12   12      4  2020     64      19
#
#   country_code  population
# 0          AFG  37172386.0
# 1          ALB   2866376.0
# 2          DZA  42228429.0

# %% [markdown]
# Let us see how many null values there are in covid_data

# %%
covid_data.isna().sum().sum() #total nan value present in covid_data df
# Out:
# 8

# %%
covid_data.isnull()#.sum().sum()
# Out:
#      country  continent   date    day  month   year  cases  deaths  \
# 0      False      False  False  False  False  False  False   False
# 1      False      False  False  False  False  False  False   False
# 2      False      False  False  False  False  False  False   False
# 3      False      False  False  False  False  False  False   False
# 4      False      False  False  False  False  False  False   False
# ..       ...        ...    ...    ...    ...    ...    ...     ...
# 201    False      False  False  False  False  False  False   False
# 202    False      False  False  False  False  False  False   False
# 203    False      False  False  False  False  False  False   False
# 204    False      False  False  False  False  False  False   False
# 205    False      False  False  False  False  False  False   False
#
#      country_code  population
# 0           False       False
# 1           False       False
# 2           False       False
# 3           False       False
# ...

# %% [markdown]
# - There are eight null values in this dataset. The sum method is used twice.
# - The first sum method calculates the total number of missing values for each column, and the second sum method adds up these values to give the number of missing values in the entire DataFrame.

# %%
 covid_data.isnull().sum()# return boolean value True for having null value
# Out:
# country         0
# continent       0
# date            0
# day             0
# month           0
# year            0
# cases           0
# deaths          0
# country_code    4
# population      4
# dtype: int64

# %%
 covid_data.notnull().sum()# return boolean value True not having null value
# Out:
# country         206
# continent       206
# date            206
# day             206
# month           206
# year            206
# cases           206
# deaths          206
# country_code    202
# population      202
# dtype: int64

# %%
covid_data.isna().any(axis=1)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 201    False
# 202    False
# 203    False
# 204    False
# 205    False
# Length: 206, dtype: bool

# %%
covid_data[covid_data.isna().any(axis=1)]  # fillter the  NaN value contained row
# Out:
#                                        country continent        date  day  \
# 5                                     Anguilla   America  2020-04-12   12
# 24           Bonaire, Saint Eustatius and Saba   America  2020-04-12   12
# 37  Cases_on_an_international_conveyance_Japan     Other  2020-01-18   18
# 61                                     Eritrea    Africa  2020-04-12   12
# 65                 Falkland_Islands_(Malvinas)   America  2020-04-12   12
#
#     month  year  cases  deaths country_code  population
# 5       4  2020      0       0          NaN         NaN
# 24      4  2020      0       0          NaN         NaN
# 37      1  2020      0       0          NaN      3000.0
# 61      4  2020      0       0          ERI         NaN
# 65      4  2020      0       0          NaN         NaN

# %% [markdown]
# - We have two options for dealing with this missing data
# - either get rid of these values (drop them), or
# - substitute these values with a suitable measure (like the mean,median, or mode) that can be used as an approximation for the missing value.

# %% [markdown]
# ### Dropping the missing data
# - The dropna method removes all the missing values in a DataFrame or Series.

# %%
dropnadf=covid_data.dropna()#df.dropna(inplace=True)

# %%
dropnadf.isna().sum()#.sum()
# Out:
# country         0
# continent       0
# date            0
# day             0
# month           0
# year            0
# cases           0
# deaths          0
# country_code    0
# population      0
# dtype: int64

# %%
dropnadf.shape
# Out:
# (201, 10)

# %%
covid_data.shape
# Out:
# (206, 10)

# %%
df.dropna(inplace=True)

# %% [markdown]
# - Note that this method creates a copy of the data frame and does not modify the original DataFrame.
# - To modify the original DataFrame, we use the inplace=True parameter.

# %% [markdown]
# ### Imputation
# - Imputation is the process of replacing missing values.
# - In Pandas, there is an option to substitute the missing values with measures of central tendencies like the mean, median,or mode, using the fillna method. You can also fill the missing values with a fixed or constant value like 0.
# - We can use the forward fill technique to fill the missing value with the value just before it,or the backward fill technique to substitute the null value with the value just after it.

# %% [markdown]
# ### forward fill - pad / ffill
# - Let us substitute the NaN value for the country "Anguilla" with the values preceding it (in the previous row), using the forward fill technique (ffill), as shown in the following.

# %%
covid_data.loc[4:7,:]
# Out:
#                country continent        date  day  month  year  cases  deaths  \
# 4               Angola    Africa  2020-04-12   12      4  2020      0       0
# 5             Anguilla   America  2020-04-12   12      4  2020      0       0
# 6  Antigua_and_Barbuda   America  2020-04-12   12      4  2020      0       0
# 7            Argentina   America  2020-04-12   12      4  2020    162       7
#
#   country_code  population
# 4          AGO  30809762.0
# 5          NaN         NaN
# 6          ATG     96286.0
# 7          ARG  44494502.0

# %%
covid_data.fillna(method='ffill',inplace=False).loc[4:7,:]  # pad/ffill forward fill method
# Out:
#                country continent        date  day  month  year  cases  deaths  \
# 4               Angola    Africa  2020-04-12   12      4  2020      0       0
# 5             Anguilla   America  2020-04-12   12      4  2020      0       0
# 6  Antigua_and_Barbuda   America  2020-04-12   12      4  2020      0       0
# 7            Argentina   America  2020-04-12   12      4  2020    162       7
#
#   country_code  population
# 4          AGO  30809762.0
# 5          AGO  30809762.0
# 6          ATG     96286.0
# 7          ARG  44494502.0

# %% [markdown]
# ### backward fill -  backfill / bfill
# - “bfill”, which substitutes the missing values with the next valid observation that occurs in the row following it.

# %%
df = pd.DataFrame([[np.nan, 2, np.nan, 0],
                    [3, 4, np.nan, 1],
                    [np.nan, np.nan, np.nan, np.nan],
                    [np.nan, 3, np.nan, 4]],
                   columns=list("ABCD"))
df
# Out:
#      A    B   C    D
# 0  NaN  2.0 NaN  0.0
# 1  3.0  4.0 NaN  1.0
# 2  NaN  NaN NaN  NaN
# 3  NaN  3.0 NaN  4.0

# %%
values = {"A":df.A.std(), "B":df.B.std() , "C": df.C.mean(), "D": df.D.mean()}
df.fillna(value=values)
# Out:
#      A    B   C         D
# 0  NaN  2.0 NaN  0.000000
# 1  3.0  4.0 NaN  1.000000
# 2  NaN  1.0 NaN  1.666667
# 3  NaN  3.0 NaN  4.000000

# %%
df.B.std()
# Out:
# 1.0

# %%
df.fillna(method='bfill',inplace=False)
# Out:
#      A    B   C    D
# 0  3.0  2.0 NaN  0.0
# 1  3.0  4.0 NaN  1.0
# 2  NaN  3.0 NaN  4.0
# 3  NaN  3.0 NaN  4.0

# %%
covid_data.loc[4:7,:]
# Out:
#                country continent        date  day  month  year  cases  deaths  \
# 4               Angola    Africa  2020-04-12   12      4  2020      0       0
# 5             Anguilla   America  2020-04-12   12      4  2020      0       0
# 6  Antigua_and_Barbuda   America  2020-04-12   12      4  2020      0       0
# 7            Argentina   America  2020-04-12   12      4  2020    162       7
#
#   country_code  population
# 4          AGO  30809762.0
# 5          NaN         NaN
# 6          ATG     96286.0
# 7          ARG  44494502.0

# %%
covid_data.fillna(method='bfill').loc[4:7,:] # backfill
# Out:
#                country continent        date  day  month  year  cases  deaths  \
# 4               Angola    Africa  2020-04-12   12      4  2020      0       0
# 5             Anguilla   America  2020-04-12   12      4  2020      0       0
# 6  Antigua_and_Barbuda   America  2020-04-12   12      4  2020      0       0
# 7            Argentina   America  2020-04-12   12      4  2020    162       7
#
#   country_code  population
# 4          AGO  30809762.0
# 5          ATG     96286.0
# 6          ATG     96286.0
# 7          ARG  44494502.0

# %% [markdown]
# ### fill with constant /scalar value

# %%
covid_data.fillna(1000).loc[4:7,:] # fill with constant /scalar value
# Out:
#                country continent        date  day  month  year  cases  deaths  \
# 4               Angola    Africa  2020-04-12   12      4  2020      0       0
# 5             Anguilla   America  2020-04-12   12      4  2020      0       0
# 6  Antigua_and_Barbuda   America  2020-04-12   12      4  2020      0       0
# 7            Argentina   America  2020-04-12   12      4  2020    162       7
#
#   country_code  population
# 4          AGO  30809762.0
# 5         1000      1000.0
# 6          ATG     96286.0
# 7          ARG  44494502.0

# %% [markdown]
# ### fill with static method
# - A standard method for imputation of missing values is to substitute the null values with the mean value of the other valid observations.
# - The fillna method can be used for this purpose, as well.
# - Here, we are substituting the missing value in each column with the mean of the other two values in the column.

# %%
covid_data.mean(numeric_only=True)
# Out:
# day           1.202427e+01
# month         3.985437e+00
# year          2.020000e+03
# cases         3.952476e+02
# deaths        2.971359e+01
# population    3.731716e+07
# dtype: float64

# %%
covid_data.fillna(covid_data.mean(numeric_only=True)).loc[4:7,:]
# Out:
#                country continent        date  day  month  year  cases  deaths  \
# 4               Angola    Africa  2020-04-12   12      4  2020      0       0
# 5             Anguilla   America  2020-04-12   12      4  2020      0       0
# 6  Antigua_and_Barbuda   America  2020-04-12   12      4  2020      0       0
# 7            Argentina   America  2020-04-12   12      4  2020    162       7
#
#   country_code    population
# 4          AGO  3.080976e+07
# 5          NaN  3.731716e+07
# 6          ATG  9.628600e+04
# 7          ARG  4.449450e+07

# %% [markdown]
# ### using Interpolation method
# - Interpolation is another technique for estimating missing values in numeric columns, with the most straightforward interpolation technique being the linear interpolation method.
# - In linear interpolation, the equation of a straight line is used to estimate unknown values from known values. If there are two points, (x0, y0) and (x1,y1), then an unknown point (x,y) can be estimated using the following equation:
# -![image.png](attachment:image.png)
# - In Pandas, there is an interpolate method that estimates an unknown value from known values.

# %%
covid_data.interpolate(method='linear').loc[4:7,:] # only applicable to numeric columns
# Out:
#                country continent        date  day  month  year  cases  deaths  \
# 4               Angola    Africa  2020-04-12   12      4  2020      0       0
# 5             Anguilla   America  2020-04-12   12      4  2020      0       0
# 6  Antigua_and_Barbuda   America  2020-04-12   12      4  2020      0       0
# 7            Argentina   America  2020-04-12   12      4  2020    162       7
#
#   country_code  population
# 4          AGO  30809762.0
# 5          NaN  15453024.0
# 6          ATG     96286.0
# 7          ARG  44494502.0

# %% [markdown]
# - The missing values in each column are interpolated using the other values in the column.
# - Further reading: See more on missing data in Pandas: https://pandas.pydata.org/pandas-docs/stable/user_guide/missing_data.html

# %% [markdown]
# ## Data duplication
# - Redundancy in data is a common occurrence with many records containing the same data.

# %%
periodic_table=pd.DataFrame({'Atomic Number':[1,2,3,4,5,5,5],'Element':['Hydrogen','Helium','Lithium','Beryllium','Boron','Boron','Boron'],
                             'Symbol':['H','He','Li','Be','B','B','B']})
periodic_table
# Out:
#    Atomic Number    Element Symbol
# 0              1   Hydrogen      H
# 1              2     Helium     He
# 2              3    Lithium     Li
# 3              4  Beryllium     Be
# 4              5      Boron      B
# 5              5      Boron      B
# 6              5      Boron      B

# %% [markdown]
# - As we can see, there are duplicates in this data (the last two rows are the same).
# - In Pandas, the presence of duplicates can be detected using the duplicated method.
# - The duplicated method returns a Boolean value for each row

# %%
periodic_table.duplicated(keep='first')
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6     True
# dtype: bool

# %%
periodic_table[periodic_table.duplicated(keep='first')]
# Out:
#    Atomic Number Element Symbol
# 5              5   Boron      B
# 6              5   Boron      B

# %% [markdown]
# - By chaining this method with the sum method, we can find the total number of duplicates in the DataFrame.

# %%
periodic_table.duplicated().sum() # no of duplicated rows
# Out:
# 2

# %% [markdown]
# ### drop_duplicates
# - Let us now get rid of the duplicates using the drop_duplicates method.

# %%
periodic_table.drop_duplicates(inplace=False,keep='last',ignore_index= True)# periodic_table
# Out:
#    Atomic Number    Element Symbol
# 0              1   Hydrogen      H
# 1              2     Helium     He
# 2              3    Lithium     Li
# 3              4  Beryllium     Be
# 4              5      Boron      B

# %% [markdown]
# - By default, the drop_duplicates method keeps the first row among all the duplicate rows.
# - If we want to keep the last row, we can use the parameter keep=’last’

# %%
periodic_table.drop_duplicates(keep='last')
# Out:
#    Atomic Number    Element Symbol
# 0              1   Hydrogen      H
# 1              2     Helium     He
# 2              3    Lithium     Li
# 3              4  Beryllium     Be
# 6              5      Boron      B

# %% [markdown]
# ## Understanding the various types of joins

# %% [markdown]
# -  Left join: All rows from the object on the left included in the combined object. Rows from the object on the right that match those from the left included.
# -  Right join: All rows from the object on the right included in the combined object. Rows from the object on the left that match those from the left included.
# -  Outer join: All rows from both objects included in the combined object (whether they match or not).
# -  Inner join: Only matching rows from both objects included.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Concat function (adding rows or columns from other objects)

# %% [markdown]
# - This function gives us the option to add both rows and columns to a Pandas object. By
# default, it works on the row axis and adds rows.

# %% [markdown]
# - Let us look at how the concat function works with an example. Here, we join two DataFrame objects vertically. The second DataFrame object is added after the last row of the first DataFrame object.

# %%
periodic_table=pd.DataFrame({'Atomic Number':[1,2,3,4,5],
                             'Element':['Hydrogen','Helium','Lithium','Beryllium','Boron'],
                             'Symbol':['H','He','Li','Be','B']})

# %%
periodic_table_extended=pd.DataFrame({'Atomic Number':[8,9,10],
                                      'Element':['Oxygen','Fluorine','Neon'],'Symbol':['O','F','Ne']})
#Join these two DataFrames just created vertically using the concat

# %%
periodic_table
# Out:
#    Atomic Number    Element Symbol
# 0              1   Hydrogen      H
# 1              2     Helium     He
# 2              3    Lithium     Li
# 3              4  Beryllium     Be
# 4              5      Boron      B

# %%
periodic_table_extended
# Out:
#    Atomic Number   Element Symbol
# 0              8    Oxygen      O
# 1              9  Fluorine      F
# 2             10      Neon     Ne

# %%
pd.concat([periodic_table,periodic_table_extended],ignore_index=True) # pandas package object method
# Out:
#    Atomic Number    Element Symbol
# 0              1   Hydrogen      H
# 1              2     Helium     He
# 2              3    Lithium     Li
# 3              4  Beryllium     Be
# 4              5      Boron      B
# 5              8     Oxygen      O
# 6              9   Fluorine      F
# 7             10       Neon     Ne

# %% [markdown]
# We can also concatenate objects side-by-side along the column axis, as shown in the
# following

# %%
pd.concat([periodic_table,periodic_table_extended],axis=1,join='inner')
# Out:
#    Atomic Number   Element Symbol  Atomic Number   Element Symbol
# 0              1  Hydrogen      H              8    Oxygen      O
# 1              2    Helium     He              9  Fluorine      F
# 2              3   Lithium     Li             10      Neon     Ne

# %% [markdown]
# - By default, the concat function performs an outer join, which returns all records of both the objects.
# - The concatenated result set will have five records (equal to the length of the longer object – the first DataFrame). Since the second DataFrame has only three rows,you can see null values for the fourth and fifth row in the final concatenated object.

# %% [markdown]
# - We can change this to an inner join by adding the join parameter.
# - By using an inner join as shown in the following, the final result set with contain only those records from both the objects where the indices match.

# %%
pd.concat([periodic_table,periodic_table_extended],axis=1,join='outer')
# Out:
#    Atomic Number    Element Symbol  Atomic Number   Element Symbol
# 0              1   Hydrogen      H            8.0    Oxygen      O
# 1              2     Helium     He            9.0  Fluorine      F
# 2              3    Lithium     Li           10.0      Neon     Ne
# 3              4  Beryllium     Be            NaN       NaN    NaN
# 4              5      Boron      B            NaN       NaN    NaN

# %% [markdown]
# We can use the keys parameter to identify each of the objects that are being concatenated, in the final result set.

# %%
pd.concat([periodic_table,periodic_table_extended],axis=1,keys=['1st periodic table','2nd periodic table'])
# Out:
#   1st periodic table                   2nd periodic table
#        Atomic Number    Element Symbol      Atomic Number   Element Symbol
# 0                  1   Hydrogen      H                8.0    Oxygen      O
# 1                  2     Helium     He                9.0  Fluorine      F
# 2                  3    Lithium     Li               10.0      Neon     Ne
# 3                  4  Beryllium     Be                NaN       NaN    NaN
# 4                  5      Boron      B                NaN       NaN    NaN

# %% [markdown]
# ## Join method – index to index
# - The join method aligns two Pandas objects based on common index values.
# - That is,it looks for matching index values in both objects and then align them vertically.
# - The default type of join for this method is a left join.
# - Let us consider the following example where we join two objects.

# %%
periodic_table=pd.DataFrame({'Atomic Number':[1,2,3,4,5],'Element':['Hydrogen','Helium','Lithium','Beryllium','Boron'],'Symbol':['H','He',
'Li','Be','B']})
periodic_table
# Out:
#    Atomic Number    Element Symbol
# 0              1   Hydrogen      H
# 1              2     Helium     He
# 2              3    Lithium     Li
# 3              4  Beryllium     Be
# 4              5      Boron      B

# %%
periodic_table_extended=pd.DataFrame({'Atomic Number':[8,9,10],'Element':['Oxygen','Fluorine','Neon'],'Symbol':['O','F','Ne']})
periodic_table_extended
# Out:
#    Atomic Number   Element Symbol
# 0              8    Oxygen      O
# 1              9  Fluorine      F
# 2             10      Neon     Ne

# %%
periodic_table.join(periodic_table_extended,lsuffix='_left',rsuffix='_right',how='outer') #default how: 'str' = 'left
#how : {'left', 'right', 'outer', 'inner'},
# Out:
#    Atomic Number_left Element_left Symbol_left  Atomic Number_right  \
# 0                   1     Hydrogen           H                  8.0
# 1                   2       Helium          He                  9.0
# 2                   3      Lithium          Li                 10.0
# 3                   4    Beryllium          Be                  NaN
# 4                   5        Boron           B                  NaN
#
#   Element_right Symbol_right
# 0        Oxygen            O
# 1      Fluorine            F
# 2          Neon           Ne
# 3           NaN          NaN
# 4           NaN          NaN

# %% [markdown]
# - Since the two DataFrame objects have common column names in the preceding example,we need to use the lsuffix and rsuffix parameters to differentiate between them. The indexes 0, 1, and 2 are common to both objects.
# - The result set includes all the rows in the first DataFrame, and if there are rows with indices not matching in the second DataFrame, the value in all these rows is a null (denoted by NaN). The default join type used for the join method is a left join.

# %% [markdown]
# ### Merge method – SQL type join based on common columns
# - Like the join method, the merge method is also used to join objects horizontally.
# - It is used when we join two DataFrame objects with a common column name.
# - The maindifference between the join and merge methods is that
# - the join method combines the objects based on common index values, while the merge method combines the objects based on common column names.
# - Another difference is that the default join type in the merge method is an inner join,
# - while the join method performs a left join of the objects by default.
# - Let us look at how the merge method works with an example. The two DataFrame objects defined here have a column name that is common – Atomic Number.
# - This is a scenario where we can apply the merge method.

# %%
periodic_table=pd.DataFrame({'Atomic Number':[1,2,3,4,5],'Element':['Hydrogen','Helium','Lithium','Beryllium','Boron'],
                             'Symbol':['H','He','Li','Be','B']})
periodic_table_extended=pd.DataFrame({'Atomic Number':[1,2,3],'Natural':'Yes'})

# %%
periodic_table
# Out:
#    Atomic Number    Element Symbol
# 0              1   Hydrogen      H
# 1              2     Helium     He
# 2              3    Lithium     Li
# 3              4  Beryllium     Be
# 4              5      Boron      B

# %%
periodic_table_extended
# Out:
#    Atomic Number Natural
# 0              1     Yes
# 1              2     Yes
# 2              3     Yes

# %%
periodic_table.merge(periodic_table_extended,how='outer',left_on='Atomic Number',right_on='Atomic Number')  # default inner join
# Out:
#    Atomic Number    Element Symbol Natural
# 0              1   Hydrogen      H     Yes
# 1              2     Helium     He     Yes
# 2              3    Lithium     Li     Yes
# 3              4  Beryllium     Be     NaN
# 4              5      Boron      B     NaN

# %% [markdown]
# The presence of a common column name is essential for a merge operation, otherwise
# we would get an error. If there is a more than one column common between the two
# DataFrames, we can mention the column on which the merge is to be performed using
# the on parameter.
# We can change the default join type (which is an inner join) using the how parameter.

# %%
periodic_table.merge(periodic_table_extended,how='outer')
# Out:
#    Atomic Number    Element Symbol Natural
# 0              1   Hydrogen      H     Yes
# 1              2     Helium     He     Yes
# 2              3    Lithium     Li     Yes
# 3              4  Beryllium     Be     NaN
# 4              5      Boron      B     NaN

# %% [markdown]
# - If we have the same column in both the objects that are being joined but their names are different, we can use parameters in the merge method to differentiate these columns.
# - In the following example, there are two columns with the same values but different names.
# - In the first DataFrame object, the name of the column is ‘Atomic Number’, while in the second DataFrame object, the name of the column is ‘Number’.

# %%
periodic_table=pd.DataFrame({'Atomic Number':[1,2,3,4,5],'Element':
['Hydrogen','Helium','Lithium','Beryllium','Boron'],'Symbol':['H','He',
'Li','Be','B']})
periodic_table_extended=pd.DataFrame({'Number':[1,2,3],'Natural':'Yes'})

# %%
periodic_table
# Out:
#    Atomic Number    Element Symbol
# 0              1   Hydrogen      H
# 1              2     Helium     He
# 2              3    Lithium     Li
# 3              4  Beryllium     Be
# 4              5      Boron      B

# %%
periodic_table_extended
# Out:
#    Number Natural
# 0       1     Yes
# 1       2     Yes
# 2       3     Yes

# %%
periodic_table.merge(periodic_table_extended)
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# Input In [170], in <cell line: 1>()
# ----> 1 periodic_table.merge(periodic_table_extended)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:9345, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9326 @Substitution("")
#    9327 @Appender(_merge_doc, indents=2)
#    9328 def merge(
#    (...)
#    9341     validate: str | None = None,
#    9342 ) -> DataFrame:
#    9343     from pandas.core.reshape.merge import merge
# -> 9345     return merge(
#    9346         self,
#    9347         right,
#    9348         how=how,
#    9349         on=on,
#    9350         left_on=left_on,
#    9351         right_on=right_on,
#    9352         left_index=left_index,
#    9353         right_index=right_index,
#    9354         sort=sort,
# ...

# %% [markdown]
# ### Using the left_on parameter for the column on the left, and right_on parameter for the column on the right, we merge the two objects as follows:

# %%
periodic_table.merge(periodic_table_extended,left_on='Atomic Number',right_on='Number')
# Out:
#    Atomic Number   Element Symbol  Number Natural
# 0              1  Hydrogen      H       1     Yes
# 1              2    Helium     He       2     Yes
# 2              3   Lithium     Li       3     Yes

# %% [markdown]
# ##### Note that append, merge, and join are all DataFrame methods used with DataFrame objects while concat is a Pandas function.
# - Further reading:
# - Merge method: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.merge.html
# - Join method: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.join.html#pandas.DataFrame.join
# - Concat function: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.concat.html
# - Append method: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.append.html
